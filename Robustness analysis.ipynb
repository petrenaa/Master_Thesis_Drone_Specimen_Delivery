# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import itertools
import random
from scipy.stats import poisson

#%pip install gurobipy
import gurobipy as gp
from gurobipy import GRB

# %% [markdown]
# Data generation

# %%
### PASSAU  ###

#Define sets of I, J, K, where J contains I and K for Passau

#Define the number of elements in each set I, J, K

degree_to_m = 111111

#Define empty data frames
I_coordinates = pd.DataFrame(columns = ['Point number', 'Latitude', 'Longitude'])
J_coordinates = pd.DataFrame(columns = ['Point number', 'Latitude', 'Longitude'])
K_coordinates = pd.DataFrame(columns = ['Point number', 'Latitude', 'Longitude'])

column_types = {
    'Name': 'str',  # Example: 'int', 'float', 'str', 'datetime64[ns]', etc.
    'Latitude': 'float',
    'Longitude': 'float',
    'Address': 'str'
    # Add more columns and their data types as needed
}

doctors = pd.read_csv('Doctors coordinates.txt', sep = ';', index_col = False, dtype=column_types)

doctors

for i in range(len(doctors['Latitude'])):
    I_coordinates.loc[i, 'Point number'] = 'i'+ str(i)
    I_coordinates.loc[i, 'Latitude'] = doctors.loc[i, 'Latitude']
    I_coordinates.loc[i, 'Longitude'] = doctors.loc[i, 'Longitude']

I_coordinates.index = I_coordinates['Point number']

I = I_coordinates * degree_to_m
I['Point number'] = I_coordinates['Point number']


labs = pd.read_csv('Labs coordinates.txt', sep = ';', index_col = False, dtype=column_types) 
labs

for k in range(len(labs['Latitude'])):
    K_coordinates.loc[k, 'Point number'] = 'k'+ str(k)
    K_coordinates.loc[k, 'Latitude'] = labs.loc[k, 'Latitude']
    K_coordinates.loc[k, 'Longitude'] = labs.loc[k, 'Longitude']

K_coordinates.index = K_coordinates['Point number']

K = K_coordinates * degree_to_m
K['Point number'] = K_coordinates['Point number']


#Define range of coordinates

combined_coordinates = pd.concat([I_coordinates, K_coordinates])

min_latitude = combined_coordinates['Latitude'].min()
max_latitude = combined_coordinates['Latitude'].max()
min_longitude = combined_coordinates['Longitude'].min()
max_longitude = combined_coordinates['Longitude'].max()

grid_spacing = 0.0018

# Create grid points
grid_points = []
for lat in np.arange(min_latitude, max_latitude + grid_spacing, grid_spacing):
    for lon in np.arange(min_longitude, max_longitude + grid_spacing, grid_spacing):
        grid_points.append((round(lat, 6), round(lon, 6)))

J_coordinates = pd.DataFrame(grid_points, columns=['Latitude', 'Longitude'])
J_coordinates['Point number'] = ['j' + str(i) for i in range(len(J_coordinates))]

J_coordinates.index = J_coordinates['Point number'] 
J_coordinates = pd.concat([J_coordinates, K_coordinates, I_coordinates], axis = 0) #Include K to J

river = ['j972', 'j973', 'j918', 'j919', 'j920', 'j866', 'j867', 'j813', 'j814',
'j815', 'j760', 'j761', 'j762', 'j707', 'j708', 'j709', 'j710', 'j654',
'j655', 'j656', 'j657', 'j658', 'j606', 'j610', 'j611', 'j612', 'j613', 'j614',
'j615', 'j616', 'j620', 'j621', 'j622', 'j623', 'j624', 'j625', 'j682', 'j683',
'j684','j685','j686', 'j635', 'j636', 'j637', 'j638', 'j585', 'j586', 'j587', 
'j588', 'j589', 'j590', 'j591', 'j592','j593', 'j531', 'j530', 'j529', 'j528',
'j527', 'j22', 'j23', 'j77', 'j132', 'j133', 'j134', 'j189', 'j190', 'j244',
'j245', 'j300', 'j301', 'j356', 'j411', 'j412', 'j467', 'j523', 'j524', 'j525', 'j526',

'j246', 'j247', 'j191', 'j192', 'j193', 'j194', 'j135', 'j136', 'j137', 'j138', 'j139',
'j140', 'j141', 'j78', 'j79', 'j80', 'j81', 'j82', 'j83', 'j84', 'j85', 'j86', 'j87', 'j88',
'j24', 'j25', 'j26', 'j27', 'j28', 'j29', 'j30', 'j31', 'j32', 'j33', 'j34', 'j35', 'j36',
 'j261', 'j262', 'j263', 'j264', 'j266', 'j267', 'j268', 'j269', 'j206', 'j207', 'j208',
'j209', 'j210', 'j211', 'j212', 'j213', 'j214', 'j215', 'j153', 'j154', 'j155', 'j156',
'j157', 'j158', 'j159', 'j160', 'j161', 'j98', 'j99', 'j100', 'j101', 'j102', 'j103', 
'j104', 'j105', 'j106', 'j107', 'j43', 'j44', 'j45', 'j46', 'j47', 'j48', 'j49', 'j50', 
'j51', 'j52', 'j53'
 ]

J_coordinates = J_coordinates.drop(index = river) #excluding locations on the river

J = J_coordinates * degree_to_m
J['Point number'] = J_coordinates['Point number']

# %%
#Define constants

B = 91800 #battery load: meters of travel
S = 5100 #meters of service time

p = 0.97

alpha = 15900 #euro

beta = {}
for j in J.index:
    if j.startswith('j'):
        beta[j] = 203000
    else:
        beta[j] = 76920
        
gamma = 0.0045 / 1000 # variable cost in euro per m
        
q_j = {}
for j in J.index:
    if j.startswith('j'):
        q_j[j] = 255
    else:
        q_j[j] = 45



softlimit = 120
hardlimit = 10000

# %%
#Define distance matrices

def distance(point1, PointsSet1, point2, PointsSet2):
    c1 = np.array((PointsSet1.loc[point1, 'Longitude'], PointsSet1.loc[point1, 'Latitude']))
    c2 = np.array((PointsSet2.loc[point2, 'Longitude'], PointsSet2.loc[point2, 'Latitude']))
    return np.linalg.norm(c1-c2)

dist_JI = {(c1, c2): distance(c1, J, c2, I)for c1, c2 in itertools.product(J.index, I.index)}
dist_IK = {(c1, c2): distance(c1, I, c2, K)for c1, c2 in itertools.product(I.index, K.index)}
dist_KJ = {(c1, c2): distance(c1, K, c2, J)for c1, c2 in itertools.product(K.index, J.index)}


 
def softtime(model, where):
    if where == GRB.Callback.MIP:
        runtime = model.cbGet(GRB.Callback.RUNTIME)
        objbst = model.cbGet(GRB.Callback.MIP_OBJBST)
        objbnd = model.cbGet(GRB.Callback.MIP_OBJBND)
        gap = abs((objbst - objbnd) / objbst)

        if runtime > softlimit and gap < 0.5:
            model.terminate()
            

def SolutionSummary(model):
    n = -1
    results = pd.DataFrame(columns = ['i', 'k', 'j', 'Number of drones'])
    for opt_sol in range(1):
        for v in model.getVars():
            if v.varName.startswith('x_ikj'):
                if v.X > 0:
                    n += 1
                    indices = v.varName[6:-1].split(',') #drop variable name and brackets and convert to a list of indices
                    results.loc[n, 'i'] = indices[0]
                    results.loc[n, 'k'] = indices[1]
                    results.loc[n, 'j'] = indices[2]
                    results.loc[n, 'Number of drones'] = int(v.X)
    results_doctors = sum(results['Number of drones'])
    return results_doctors


total_drones = pd.DataFrame(columns = ['Prob model number of drones', 'Actual number of drones'])
o = 0

# %%
for i in range(0, 50):
    up_bound = 10
    mu = {i : int(round(random.uniform(1, up_bound), 0)) for i in I.index}

    theta_det = {}
    for n in I.index:
        theta_det[n] = list(poisson.rvs(mu[n], size = 1))[0]
    theta_det


    #Define set L
    L = list()
    for k, j in itertools.product(K.index, J.index):
        if dist_KJ[(k, j)] <= 0.5*B:
            L.append((k, j))
            


    #Define set P
    P = list()
    for i, k in itertools.product(I.index, K.index):
        if dist_IK[(i, k)] <= 0.5*B:
            P.append((i, k))


    #Define sets M_kj

    M_kj = {}
    M_interim = []

    for (k, j) in L:
        for i in I.index:
            if dist_JI[j, i] <= S:
                if dist_JI[j, i] + dist_IK[i, k] + dist_KJ[k, j] <= B:
                    M_interim.append(i)
        M_kj[(k, j)] = M_interim
        M_interim = []

    M_kj_final = {key : val for key, val in M_kj.items() if val != []}  

    KJ_feas = list(M_kj_final.keys())



    #Define sets N_i

    N_i = {}
    N_interim = []

    for i in I.index:
        for (k, j) in L:
            if dist_JI[j, i] <= S:
                if dist_JI[j, i] + dist_IK[i, k] + dist_KJ[k, j] <= B:
                    N_interim.append((k, j))
        N_i[i] = N_interim
        N_interim = []
        
    N_i_final = {key : val for key, val in N_i.items() if val != []}   
    
    I_feas = list(N_i_final.keys())



    #Define sets O_j

    O_j = {}
    O_interim = []

    for j in J.index:
        for (i, k) in P:
            if dist_JI[j, i] <= S:
                if dist_JI[j, i] + dist_IK[i, k] + dist_KJ[k, j] <= B:
                    O_interim.append((i, k))
        O_j[j] = O_interim
        O_interim = []
        
    O_j_final = {key : val for key, val in O_j.items() if val != []}   
    
    J_feas = list(O_j_final.keys())




    #Define constants and random variables

    theta_ran_i = {}
    for n in list(I.index):
        theta_ran_i[n] = poisson(mu[n])

    l_i = {}
    for i in theta_ran_i.keys():
        l_i[i] = int(theta_ran_i[i].ppf(p))


    g_i = {}
    for i in theta_ran_i.keys():
        g_i[i] = mu[i] * 7

    IG = []
    for i in I.index:
        for g in range(1, g_i[i] + 1):
            IG.append((i, g))

    I_feasG = []
    for i in I_feas:
        for g in range(1, g_i[i] + 1):
            I_feasG.append((i, g))
            

    h_ig = {}
    for (i, g) in I_feasG:
        h_ig[(i, g)] = math.log(theta_ran_i[i].cdf(l_i[i] + g)) - math.log(theta_ran_i[i].cdf(l_i[i] + g - 1))


    phi = float(math.log(p) - sum(theta_ran_i[i].cdf(l_i[i]) for i in I_feas))
    g_i



    model_prob = gp.Model('Probabilistic model without relaxation')

    x_ikj = model_prob.addVars(I.index, L, vtype = GRB.INTEGER, name = 'x_ikj')
    y_j = model_prob.addVars(J.index, vtype = GRB.BINARY, name = 'y_j')
    z_ig = model_prob.addVars(IG, vtype = GRB.BINARY, name = 'z_ig')

    #Probabilistic constraints

    model_prob.addConstr((gp.quicksum(h_ig[ig] * z_ig[ig] for ig in I_feasG)) >= phi, name = 'c15')
    model_prob.addConstrs((gp.quicksum(x_ikj[i, k, j] for (k, j) in N_i_final[i]) == l_i[i] + gp.quicksum(z_ig) for (i, g) in I_feasG), name = 'c16')


    #Same constraints as in the deterministic model

    model_prob.addConstrs((gp.quicksum(x_ikj[i, k, j] for (i, k) in O_j_final[j]) <= q_j[j] * y_j[j] for j in J_feas), name = 'c4')
    model_prob.addConstrs(((dist_JI[(j, i)] + dist_IK[(i, k)] + dist_KJ[(k, j)]) * x_ikj[i, k, j] <= B * x_ikj[i, k, j]
                    for i in I_feas for (k, j) in KJ_feas), name = 'c5')
    model_prob.addConstrs((dist_JI[(j, i)] * x_ikj[i, k, j] <= S * x_ikj[i, k, j] for i in I_feas for (k, j) in KJ_feas), name = 'c6')

    model_prob.setObjective(gp.quicksum(alpha * x_ikj[i, k, j] + gamma * (dist_JI[(j, i)] + dist_IK[(i, k)] + dist_KJ[(k, j)]) * x_ikj[i, k, j] for i in I_feas for (k, j) in KJ_feas) + gp.quicksum(beta[j] * y_j[j] for j in J_feas), GRB.MINIMIZE)

    model_prob.setParam('TimeLimit', hardlimit)
    model_prob.optimize(softtime)
    
    total_drones.loc[o, 'Prob model number of drones'] = SolutionSummary(model_prob)
    total_drones.loc[o, 'Actual number of drones'] = sum(theta_det.values())
    o += 1
# Out:
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Set parameter TimeLimit to value 10000
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1145G7 @ 2.60GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 165570 rows, 84873 columns and 12640872 nonzeros
# Model fingerprint: 0xd872353b
# Variable types: 0 continuous, 84873 integer (4177 binary)
# Coefficient statistics:
#   Matrix range     [1e-13, 9e+04]
#   Objective range  [2e+04, 2e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 8e+01]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 2.730357e+07
# Presolve removed 161393 rows and 19513 columns (presolve time = 8s) ...
# Presolve removed 164445 rows and 19513 columns
# Presolve time: 9.14s
# Presolved: 1125 rows, 65360 columns, 129747 nonzeros
# Variable types: 0 continuous, 65360 integer (1048 binary)
# Found heuristic solution: objective 2.730357e+07
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    8.1999850e+06   8.587500e+01   5.734500e+10     10s
#       77    2.1594781e+08   0.000000e+00   1.306054e+07     10s
#     8225    1.3690823e+07   0.000000e+00   0.000000e+00     10s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.369082e+07, 8225 iterations, 0.20 seconds (0.17 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.3691e+07    0   49 2.7304e+07 1.3691e+07  49.9%     -    9s
# H    0     0                    2.298504e+07 1.3691e+07  40.4%     -    9s
# H    0     0                    2.278204e+07 1.3691e+07  39.9%     -    9s
# H    0     0                    1.773480e+07 1.3691e+07  22.8%     -    9s
# H    0     0                    1.385004e+07 1.3691e+07  1.15%     -   12s
#      0     0 1.3691e+07    0   87 1.3850e+07 1.3691e+07  1.15%     -   12s
#      0     0 1.3691e+07    0   90 1.3850e+07 1.3691e+07  1.15%     -   13s
#      0     0 1.3691e+07    0  150 1.3850e+07 1.3691e+07  1.15%     -   13s
#      0     0 1.3691e+07    0  150 1.3850e+07 1.3691e+07  1.15%     -   14s
#      0     0 1.3691e+07    0  172 1.3850e+07 1.3691e+07  1.15%     -   14s
# H    0     0                    1.385004e+07 1.3691e+07  1.15%     -   14s
# H    0     0                    1.385004e+07 1.3691e+07  1.15%     -   16s
#      0     2 1.3691e+07    0  172 1.3850e+07 1.3691e+07  1.15%     -   16s
#     50    98 1.3691e+07   14  181 1.3850e+07 1.3691e+07  1.15%  44.1   20s
#    275   787 1.3691e+07   61  115 1.3850e+07 1.3691e+07  1.15%  38.1   26s
# H  943  1177                    1.380088e+07 1.3691e+07  0.80%  31.0   28s
# H 1176  1513                    1.380088e+07 1.3691e+07  0.80%  31.3   30s
# H 1464  1513                    1.380088e+07 1.3691e+07  0.80%  32.9   30s
# H 1512  1756                    1.380088e+07 1.3691e+07  0.80%  32.0   34s
# H 1637  1756                    1.380088e+07 1.3691e+07  0.80%  32.1   34s
#   1755  2341 1.3691e+07  532   22 1.3801e+07 1.3691e+07  0.80%  32.7   37s
# H 1758  2341                    1.380088e+07 1.3691e+07  0.80%  32.7   37s
#   2340  3425 1.3691e+07  691   13 1.3801e+07 1.3691e+07  0.80%  28.1   40s
# H 4375  4539                    1.380088e+07 1.3691e+07  0.80%  22.7   45s
#   4585  4543 1.3691e+07   52  175 1.3801e+07 1.3691e+07  0.80%  24.1   50s
#   4592  4548 1.3691e+07  322  314 1.3801e+07 1.3691e+07  0.80%  24.0   55s
#   4620  4572 1.3691e+07   15  214 1.3801e+07 1.3691e+07  0.80%  29.9   60s
# H 4654  4388                    1.380088e+07 1.3691e+07  0.80%  32.2   62s
#   4680  4458 1.3691e+07   20  187 1.3801e+07 1.3691e+07  0.80%  32.2   66s
#   4758  4747 1.3691e+07   26  222 1.3801e+07 1.3691e+07  0.80%  33.1   73s
#   5073  4903 1.3691e+07   38  153 1.3801e+07 1.3691e+07  0.80%  34.6   80s
#   5336  5008 1.3691e+07   61  296 1.3801e+07 1.3691e+07  0.80%  41.0   87s
#   5557  5014 1.3691e+07   83  276 1.3801e+07 1.3691e+07  0.80%  47.9   94s
#   5659  5117 1.3691e+07   98  259 1.3801e+07 1.3691e+07  0.80%  55.8  102s
#   5804  5209 1.3691e+07  125  216 1.3801e+07 1.3691e+07  0.80%  66.0  110s
#   5946  5446 1.3691e+07  138  170 1.3801e+07 1.3691e+07  0.80%  71.9  120s
# H 6229  5135                    1.380088e+07 1.3691e+07  0.80%  78.0  120s
#
# Cutting planes:
#   Gomory: 6
#   Lift-and-project: 7
#   Implied bound: 425
#   MIR: 37
#   StrongCG: 10
#   Flow cover: 52
#   Zero half: 7
#   Relax-and-lift: 40
#
# Explored 6230 nodes (494649 simplex iterations) in 121.03 seconds (155.81 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 1.38009e+07 1.38009e+07 1.38009e+07 ... 1.385e+07
#
# Solve interrupted
# Best objective 1.380087840571e+07, best bound 1.369082268850e+07, gap 0.7975%
#
# User-callback calls 17748, time in user-callback 0.12 sec
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Set parameter TimeLimit to value 10000
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1145G7 @ 2.60GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 165584 rows, 84887 columns and 12735710 nonzeros
# Model fingerprint: 0xdb1ce03b
# Variable types: 0 continuous, 84887 integer (4191 binary)
# Coefficient statistics:
#   Matrix range     [1e-13, 9e+04]
#   Objective range  [2e+04, 2e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 8e+01]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 2.723997e+07
# Presolve removed 161393 rows and 19527 columns (presolve time = 10s) ...
# Presolve removed 164459 rows and 19527 columns (presolve time = 10s) ...
# Presolve removed 164459 rows and 19527 columns
# Presolve time: 10.82s
# Presolved: 1125 rows, 65360 columns, 129747 nonzeros
# Variable types: 0 continuous, 65360 integer (1048 binary)
# Found heuristic solution: objective 2.723997e+07
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    8.1599850e+06   8.412500e+01   5.734500e+10     11s
#       80    2.1588421e+08   0.000000e+00   1.306033e+07     11s
#     7940    1.3624038e+07   0.000000e+00   0.000000e+00     11s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.362404e+07, 7940 iterations, 0.15 seconds (0.17 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.3624e+07    0   48 2.7240e+07 1.3624e+07  50.0%     -   11s
# H    0     0                    2.271844e+07 1.3624e+07  40.0%     -   11s
# H    0     0                    2.231244e+07 1.3624e+07  38.9%     -   11s
# H    0     0                    1.815412e+07 1.3624e+07  25.0%     -   11s
# H    0     0                    1.378644e+07 1.3624e+07  1.18%     -   15s
#      0     0 1.3624e+07    0   95 1.3786e+07 1.3624e+07  1.18%     -   15s
#      0     0 1.3624e+07    0   99 1.3786e+07 1.3624e+07  1.18%     -   16s
# H    0     0                    1.378644e+07 1.3624e+07  1.18%     -   16s
#      0     0 1.3624e+07    0  142 1.3786e+07 1.3624e+07  1.18%     -   16s
#      0     0 1.3624e+07    0  159 1.3786e+07 1.3624e+07  1.18%     -   17s
#      0     0 1.3624e+07    0  174 1.3786e+07 1.3624e+07  1.18%     -   17s
#      0     0 1.3624e+07    0  174 1.3786e+07 1.3624e+07  1.18%     -   17s
#      0     2 1.3624e+07    0  174 1.3786e+07 1.3624e+07  1.18%     -   19s
#     19    24 1.3624e+07    6  173 1.3786e+07 1.3624e+07  1.18%  50.3   20s
#    102   258 1.3624e+07   24  131 1.3786e+07 1.3624e+07  1.18%  37.0   25s
# H  343   677                    1.373728e+07 1.3624e+07  0.82%  38.8   29s
# H  676   895                    1.373728e+07 1.3624e+07  0.82%  36.2   34s
#    894  1627 1.3624e+07  129   61 1.3737e+07 1.3624e+07  0.82%  33.3   39s
#   1626  2035 1.3624e+07  405   49 1.3737e+07 1.3624e+07  0.82%  31.4   42s
#   2034  2261 1.3624e+07  545   45 1.3737e+07 1.3624e+07  0.82%  32.1   49s
#   2260  3346 1.3624e+07  696   20 1.3737e+07 1.3624e+07  0.82%  32.4   52s
#   3347  4323 1.3624e+07  931    3 1.3737e+07 1.3624e+07  0.82%  27.9   56s
# H 4482  4645                    1.373728e+07 1.3624e+07  0.82%  23.6   58s
#   4689  5097 1.3624e+07  229   30 1.3737e+07 1.3624e+07  0.82%  23.4   61s
#   5144  5099 1.3624e+07  880   52 1.3737e+07 1.3624e+07  0.82%  23.6   65s
#   5151  5104 1.3624e+07  619  214 1.3737e+07 1.3624e+07  0.82%  23.6   70s
#   5180  5128 1.3624e+07   18  200 1.3737e+07 1.3624e+07  0.82%  28.3   75s
#   5265  5268 1.3624e+07   27  255 1.3737e+07 1.3624e+07  0.82%  28.8   83s
# H 5293  5003                    1.373728e+07 1.3624e+07  0.82%  29.1   83s
#   5352  5172 1.3624e+07   37  176 1.3737e+07 1.3624e+07  0.82%  29.4   90s
#   5547  5587 1.3624e+07   61  270 1.3737e+07 1.3624e+07  0.82%  31.5  100s
#   6029  5836 1.3624e+07  113  174 1.3737e+07 1.3624e+07  0.82%  32.9  107s
#   6446  6122 1.3624e+07  152  244 1.3737e+07 1.3624e+07  0.82%  34.3  113s
#   6902  6363 1.3624e+07  180  244 1.3737e+07 1.3624e+07  0.82%  34.9  120s
#
# Cutting planes:
#   Gomory: 6
#   Lift-and-project: 6
#   Implied bound: 365
#   MIR: 20
#   StrongCG: 11
#   Flow cover: 63
#   Zero half: 9
#   Network: 1
#   Relax-and-lift: 40
#
# Explored 7334 nodes (276593 simplex iterations) in 120.22 seconds (121.24 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 1.37373e+07 1.37373e+07 1.37373e+07 ... 2.724e+07
#
# Solve interrupted
# Best objective 1.373727777089e+07, best bound 1.362403774082e+07, gap 0.8243%
#
# User-callback calls 18648, time in user-callback 0.12 sec
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Set parameter TimeLimit to value 10000
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1145G7 @ 2.60GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 165388 rows, 84691 columns and 11384730 nonzeros
# Model fingerprint: 0x56ab8142
# Variable types: 0 continuous, 84691 integer (3995 binary)
# Coefficient statistics:
#   Matrix range     [1e-13, 9e+04]
#   Objective range  [2e+04, 2e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 8e+01]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 2.655626e+07
# Presolve removed 161393 rows and 19331 columns (presolve time = 7s) ...
# Presolve removed 164263 rows and 19331 columns
# Presolve time: 7.82s
# Presolved: 1125 rows, 65360 columns, 129747 nonzeros
# Variable types: 0 continuous, 65360 integer (1048 binary)
# Found heuristic solution: objective 2.655626e+07
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    7.7299858e+06   7.750000e+01   6.049300e+10      8s
#       79    2.1520051e+08   0.000000e+00   1.305987e+07      8s
#     8162    1.2906104e+07   0.000000e+00   0.000000e+00      8s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.290610e+07, 8162 iterations, 0.19 seconds (0.17 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.2906e+07    0   54 2.6556e+07 1.2906e+07  51.4%     -    8s
# H    0     0                    2.325274e+07 1.2906e+07  44.5%     -    8s
# H    0     0                    2.304974e+07 1.2906e+07  44.0%     -    8s
# H    0     0                    1.767342e+07 1.2906e+07  27.0%     -    8s
# H    0     0                    1.310274e+07 1.2906e+07  1.50%     -   10s
# H    0     0                    1.310274e+07 1.2906e+07  1.50%     -   11s
# H    0     0                    1.297666e+07 1.2906e+07  0.54%     -   11s
#      0     0 1.2906e+07    0   78 1.2977e+07 1.2906e+07  0.54%     -   11s
# H    0     0                    1.297666e+07 1.2906e+07  0.54%     -   12s
#      0     0 1.2906e+07    0   80 1.2977e+07 1.2906e+07  0.54%     -   12s
#      0     0 1.2906e+07    0  155 1.2977e+07 1.2906e+07  0.54%     -   12s
#      0     0 1.2906e+07    0  165 1.2977e+07 1.2906e+07  0.54%     -   12s
#      0     0 1.2906e+07    0  177 1.2977e+07 1.2906e+07  0.54%     -   12s
#      0     0 1.2906e+07    0  177 1.2977e+07 1.2906e+07  0.54%     -   13s
#      0     2 1.2906e+07    0  177 1.2977e+07 1.2906e+07  0.54%     -   14s
#      7    12 1.2906e+07    3  206 1.2977e+07 1.2906e+07  0.54%   104   15s
# H   27    32                    1.297666e+07 1.2906e+07  0.54%  66.7   16s
#    251   545 1.2906e+07   41  150 1.2977e+07 1.2906e+07  0.54%  45.8   24s
#    544  1255 1.2906e+07  115   83 1.2977e+07 1.2906e+07  0.54%  36.9   27s
#   1254  1732 1.2906e+07  309   49 1.2977e+07 1.2906e+07  0.54%  34.2   30s
#   2249  2718 1.2906e+07  614   27 1.2977e+07 1.2906e+07  0.54%  29.7   35s
#   3589  4121 1.2906e+07  902    2 1.2977e+07 1.2906e+07  0.54%  24.7   40s
#   4979  4762 1.2906e+07  444  177 1.2977e+07 1.2906e+07  0.54%  24.4   45s
#   4986  4767 1.2906e+07  135  208 1.2977e+07 1.2906e+07  0.54%  24.4   50s
#   4993  4776 1.2906e+07   15  272 1.2977e+07 1.2906e+07  0.54%  27.2   55s
#   5065  4891 1.2906e+07   22  198 1.2977e+07 1.2906e+07  0.54%  27.6   60s
#   5137  5005 1.2906e+07   27  282 1.2977e+07 1.2906e+07  0.54%  28.1   65s
#   5275  5244 1.2906e+07   34  258 1.2977e+07 1.2906e+07  0.54%  28.6   73s
#   5596  5428 1.2906e+07   49  262 1.2977e+07 1.2906e+07  0.54%  32.3   80s
#   5919  5657 1.2906e+07  113  263 1.2977e+07 1.2906e+07  0.54%  35.8   85s
#   6255  5815 1.2906e+07  164  186 1.2977e+07 1.2906e+07  0.54%  37.7   90s
#   6553  5908 1.2906e+07  188  193 1.2977e+07 1.2906e+07  0.54%  40.6   97s
#   6746  6161 1.2906e+07  188   85 1.2977e+07 1.2906e+07  0.54%  40.2  104s
#   7117  6215 1.2906e+07  214  221 1.2977e+07 1.2906e+07  0.54%  42.1  108s
#   7313  6634 1.2906e+07  231  207 1.2977e+07 1.2906e+07  0.54%  45.1  114s
#   7803  6958 1.2906e+07  258  207 1.2977e+07 1.2906e+07  0.54%  46.6  120s
#
# Cutting planes:
#   Gomory: 4
#   Lift-and-project: 4
#   Implied bound: 362
#   MIR: 41
#   StrongCG: 12
#   Flow cover: 61
#   Zero half: 9
#   Network: 1
#   Relax-and-lift: 55
#
# Explored 8330 nodes (404253 simplex iterations) in 120.72 seconds (132.25 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 1.29767e+07 1.29767e+07 1.29767e+07 ... 2.65563e+07
#
# Solve interrupted
# Best objective 1.297665532350e+07, best bound 1.290610391780e+07, gap 0.5437%
#
# User-callback calls 20399, time in user-callback 0.08 sec
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Set parameter TimeLimit to value 10000
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1145G7 @ 2.60GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 165353 rows, 84656 columns and 11135065 nonzeros
# Model fingerprint: 0x108238b3
# Variable types: 0 continuous, 84656 integer (3960 binary)
# Coefficient statistics:
#   Matrix range     [1e-13, 9e+04]
#   Objective range  [2e+04, 2e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 8e+01]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 2.650856e+07
# Presolve removed 161393 rows and 19296 columns (presolve time = 8s) ...
# Presolve removed 164228 rows and 19296 columns
# Presolve time: 9.19s
# Presolved: 1125 rows, 65360 columns, 129747 nonzeros
# Variable types: 0 continuous, 65360 integer (1048 binary)
# Found heuristic solution: objective 2.650856e+07
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    7.6999857e+06   7.875000e+01   5.734500e+10     10s
#       77    2.1515281e+08   0.000000e+00   1.306031e+07     10s
#     7865    1.2856016e+07   0.000000e+00   0.000000e+00     10s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.285602e+07, 7865 iterations, 0.18 seconds (0.17 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.2856e+07    0   53 2.6509e+07 1.2856e+07  51.5%     -    9s
# H    0     0                    2.300204e+07 1.2856e+07  44.1%     -    9s
# H    0     0                    2.279904e+07 1.2856e+07  43.6%     -    9s
# H    0     0                    1.742272e+07 1.2856e+07  26.2%     -   10s
# H    0     0                    1.305504e+07 1.2856e+07  1.52%     -   13s
# H    0     0                    1.305504e+07 1.2856e+07  1.52%     -   13s
#      0     0 1.2856e+07    0   86 1.3055e+07 1.2856e+07  1.52%     -   13s
#      0     0 1.2856e+07    0   92 1.3055e+07 1.2856e+07  1.52%     -   15s
#      0     0 1.2856e+07    0  167 1.3055e+07 1.2856e+07  1.52%     -   15s
#      0     0 1.2856e+07    0  176 1.3055e+07 1.2856e+07  1.52%     -   15s
#      0     0 1.2856e+07    0  167 1.3055e+07 1.2856e+07  1.52%     -   15s
#      0     0 1.2856e+07    0  167 1.3055e+07 1.2856e+07  1.52%     -   16s
# H    0     0                    1.305504e+07 1.2856e+07  1.52%     -   17s
#      0     2 1.2856e+07    0  167 1.3055e+07 1.2856e+07  1.52%     -   17s
#     44    68 1.2856e+07   11  179 1.3055e+07 1.2856e+07  1.52%  43.9   20s
#    157   368 1.2856e+07   34  153 1.3055e+07 1.2856e+07  1.52%  28.6   25s
# H  367   935                    1.292896e+07 1.2856e+07  0.56%  35.9   30s
#   1258  1725 1.2856e+07  414   36 1.2929e+07 1.2856e+07  0.56%  22.4   37s
# H 1593  1725                    1.292896e+07 1.2856e+07  0.56%  22.3   37s
#   1724  2025 1.2856e+07  546   22 1.2929e+07 1.2856e+07  0.56%  21.3   43s
#   2024  2597 1.2856e+07  654   17 1.2929e+07 1.2856e+07  0.56%  22.9   47s
#   2596  3288 1.2856e+07  784   12 1.2929e+07 1.2856e+07  0.56%  21.1   51s
#   4014  4575 1.2856e+07  129   35 1.2929e+07 1.2856e+07  0.56%  18.9   58s
#   4604  5159 1.2856e+07  189   32 1.2929e+07 1.2856e+07  0.56%  19.7   61s
#   5197  5161 1.2856e+07  148   50 1.2929e+07 1.2856e+07  0.56%  18.7   65s
# H 5197  4902                    1.292896e+07 1.2856e+07  0.56%  18.7   66s
#   5206  4908 1.2856e+07   71  217 1.2929e+07 1.2856e+07  0.56%  18.6   71s
#   5237  4934 1.2856e+07   17  219 1.2929e+07 1.2856e+07  0.56%  21.9   75s
#   5347  5154 1.2856e+07   36  129 1.2929e+07 1.2856e+07  0.56%  26.2   83s
#   5498  5598 1.2856e+07   60  213 1.2929e+07 1.2856e+07  0.56%  29.5   91s
#   5992  5721 1.2856e+07  141  128 1.2929e+07 1.2856e+07  0.56%  35.6   97s
#   6280  5755 1.2856e+07  232  118 1.2929e+07 1.2856e+07  0.56%  39.6  103s
#   6410  5963 1.2856e+07  266  209 1.2929e+07 1.2856e+07  0.56%  44.0  108s
#   6661  6141 1.2856e+07  311  110 1.2929e+07 1.2856e+07  0.56%  49.3  115s
#   6923  6390 1.2856e+07  347   81 1.2929e+07 1.2856e+07  0.56%  53.8  120s
#
# Cutting planes:
#   Implied bound: 220
#   Flow cover: 40
#   Network: 1
#   Relax-and-lift: 28
#
# Explored 7259 nodes (428506 simplex iterations) in 121.10 seconds (110.74 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 1.2929e+07 1.2929e+07 1.2929e+07 ... 2.65086e+07
#
# Solve interrupted
# Best objective 1.292895579581e+07, best bound 1.285601617249e+07, gap 0.5642%
#
# User-callback calls 19791, time in user-callback 0.20 sec
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Set parameter TimeLimit to value 10000
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1145G7 @ 2.60GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 165206 rows, 84509 columns and 10143086 nonzeros
# Model fingerprint: 0x108c99a0
# Variable types: 0 continuous, 84509 integer (3813 binary)
# Coefficient statistics:
#   Matrix range     [1e-13, 9e+04]
#   Objective range  [2e+04, 2e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 8e+01]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 2.601566e+07
# Presolve removed 161393 rows and 19149 columns (presolve time = 7s) ...
# Presolve removed 164081 rows and 19149 columns
# Presolve time: 8.24s
# Presolved: 1125 rows, 65360 columns, 129747 nonzeros
# Variable types: 0 continuous, 65360 integer (1048 binary)
# Found heuristic solution: objective 2.601566e+07
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    7.3899862e+06   7.162500e+01   5.734500e+10      9s
#       75    2.1465990e+08   0.000000e+00   1.306037e+07      9s
#     7674    1.2338436e+07   0.000000e+00   0.000000e+00      9s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.233844e+07, 7674 iterations, 0.21 seconds (0.17 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.2338e+07    0   50 2.6016e+07 1.2338e+07  52.6%     -    8s
# H    0     0                    2.190013e+07 1.2338e+07  43.7%     -    8s
# H    0     0                    1.713282e+07 1.2338e+07  28.0%     -    8s
# H    0     0                    1.235913e+07 1.2338e+07  0.17%     -   12s
#      0     0 1.2338e+07    0   75 1.2359e+07 1.2338e+07  0.17%     -   12s
# H    0     0                    1.235913e+07 1.2338e+07  0.17%     -   13s
#      0     0 1.2338e+07    0   81 1.2359e+07 1.2338e+07  0.17%     -   13s
#      0     0 1.2338e+07    0  158 1.2359e+07 1.2338e+07  0.17%     -   14s
#      0     0 1.2338e+07    0  167 1.2359e+07 1.2338e+07  0.17%     -   14s
#      0     0 1.2338e+07    0  169 1.2359e+07 1.2338e+07  0.17%     -   14s
#      0     0 1.2338e+07    0  169 1.2359e+07 1.2338e+07  0.17%     -   14s
#      0     2 1.2338e+07    0  169 1.2359e+07 1.2338e+07  0.17%     -   16s
#    119   273 1.2338e+07   20  124 1.2359e+07 1.2338e+07  0.17%  17.2   20s
#    662  1069 1.2338e+07   94  109 1.2359e+07 1.2338e+07  0.17%  18.9   26s
#   1605  2049 1.2338e+07  253   92 1.2359e+07 1.2338e+07  0.17%  15.8   30s
#   2533  2945 1.2338e+07  391   87 1.2359e+07 1.2338e+07  0.17%  15.5   35s
#   3030  3563 1.2338e+07  598   28 1.2359e+07 1.2338e+07  0.17%  16.6   41s
#   4401  4774 1.2338e+07   15  116 1.2359e+07 1.2338e+07  0.17%  16.9   45s
#   5370  5242 1.2338e+07  141  111 1.2359e+07 1.2338e+07  0.17%  17.9   50s
#   5377  5247 1.2338e+07  161  240 1.2359e+07 1.2338e+07  0.17%  17.9   55s
#   5426  5311 1.2338e+07   17  259 1.2359e+07 1.2338e+07  0.17%  22.4   60s
#   5521  5499 1.2338e+07   26  262 1.2359e+07 1.2338e+07  0.17%  22.9   67s
#   5678  5852 1.2338e+07   36  257 1.2359e+07 1.2338e+07  0.17%  23.5   74s
#   6120  5816 1.2338e+07   96  250 1.2359e+07 1.2338e+07  0.17%  27.3   79s
#   6267  6055 1.2338e+07  109  163 1.2359e+07 1.2338e+07  0.17%  32.2   84s
#   6593  6122 1.2338e+07  131  151 1.2359e+07 1.2338e+07  0.17%  35.8   89s
#   6867  6220 1.2338e+07  144   65 1.2359e+07 1.2338e+07  0.17%  39.4   95s
#   7144  6437 1.2338e+07  160  123 1.2359e+07 1.2338e+07  0.17%  43.9  101s
#   7553  6450 1.2338e+07  182  107 1.2359e+07 1.2338e+07  0.17%  48.3  106s
#   7739  6531 1.2338e+07  202   97 1.2359e+07 1.2338e+07  0.17%  52.1  111s
#   7908  6670 1.2338e+07  216   98 1.2359e+07 1.2338e+07  0.17%  54.7  117s
#   8163  6802 1.2338e+07  250   40 1.2359e+07 1.2338e+07  0.17%  60.0  123s
#
# Cutting planes:
#   Gomory: 9
#   Lift-and-project: 6
#   Implied bound: 328
#   MIR: 35
#   StrongCG: 5
#   Flow cover: 56
#   Zero half: 11
#   Relax-and-lift: 43
#
# Explored 8418 nodes (526075 simplex iterations) in 123.94 seconds (142.18 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 1.23591e+07 1.23591e+07 1.71328e+07 ... 2.60157e+07
#
# Solve interrupted
# Best objective 1.235913384401e+07, best bound 1.233843574003e+07, gap 0.1675%
#
# User-callback calls 21955, time in user-callback 0.14 sec
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Set parameter TimeLimit to value 10000
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1145G7 @ 2.60GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 165010 rows, 84313 columns and 8958769 nonzeros
# Model fingerprint: 0x1f16c5dd
# Variable types: 0 continuous, 84313 integer (3617 binary)
# Coefficient statistics:
#   Matrix range     [1e-13, 9e+04]
#   Objective range  [2e+04, 2e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 8e+01]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 2.539556e+07
# Presolve removed 161393 rows and 18953 columns (presolve time = 6s) ...
# Presolve removed 163885 rows and 18953 columns
# Presolve time: 6.54s
# Presolved: 1125 rows, 65360 columns, 129747 nonzeros
# Variable types: 0 continuous, 65360 integer (1048 binary)
# Found heuristic solution: objective 2.539556e+07
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.9999875e+06   7.475000e+01   5.734500e+10      7s
#       79    2.1403980e+08   0.000000e+00   1.306033e+07      7s
#     7764    1.1687289e+07   0.000000e+00   0.000000e+00      7s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.168729e+07, 7764 iterations, 0.18 seconds (0.17 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.1687e+07    0   47 2.5396e+07 1.1687e+07  54.0%     -    7s
# H    0     0                    2.067103e+07 1.1687e+07  43.5%     -    7s
# H    0     0                    2.046803e+07 1.1687e+07  42.9%     -    7s
# H    0     0                    1.694648e+07 1.1687e+07  31.0%     -    7s
# H    0     0                    1.173903e+07 1.1687e+07  0.44%     -    9s
#      0     0 1.1687e+07    0   78 1.1739e+07 1.1687e+07  0.44%     -    9s
# H    0     0                    1.173903e+07 1.1687e+07  0.44%     -   10s
#      0     0 1.1687e+07    0   80 1.1739e+07 1.1687e+07  0.44%     -   10s
#      0     0 1.1687e+07    0  143 1.1739e+07 1.1687e+07  0.44%     -   11s
#      0     0 1.1687e+07    0  151 1.1739e+07 1.1687e+07  0.44%     -   11s
#      0     0 1.1687e+07    0  185 1.1739e+07 1.1687e+07  0.44%     -   11s
#      0     2 1.1687e+07    0  185 1.1739e+07 1.1687e+07  0.44%     -   13s
#     27    32 1.1687e+07    8  175 1.1739e+07 1.1687e+07  0.44%  45.5   15s
#    260   701 1.1687e+07   38  146 1.1739e+07 1.1687e+07  0.44%  24.0   20s
#   1070  1596 1.1687e+07  172   80 1.1739e+07 1.1687e+07  0.44%  19.6   25s
#   2454  3133 1.1687e+07  506   40 1.1739e+07 1.1687e+07  0.44%  20.0   31s
#   3689  3895 1.1701e+07  972    3 1.1739e+07 1.1687e+07  0.44%  22.0   35s
#   4640  4495 1.1687e+07  492   50 1.1739e+07 1.1687e+07  0.44%  24.1   42s
#   4650  4502 1.1687e+07  170  214 1.1739e+07 1.1687e+07  0.44%  24.0   46s
#   4680  4521 1.1687e+07   14   99 1.1739e+07 1.1687e+07  0.44%  27.5   53s
#   4736  4622 1.1687e+07   21  110 1.1739e+07 1.1687e+07  0.44%  28.6   56s
#   4812  4777 1.1687e+07   31  205 1.1739e+07 1.1687e+07  0.44%  29.7   61s
#   5000  5048 1.1687e+07   50  114 1.1739e+07 1.1687e+07  0.44%  32.0   71s
#   5360  5243 1.1687e+07  163  161 1.1739e+07 1.1687e+07  0.44%  40.9   76s
#   5701  5446 1.1687e+07  255  142 1.1739e+07 1.1687e+07  0.44%  47.7   81s
#   6031  5673 1.1687e+07  307  116 1.1739e+07 1.1687e+07  0.44%  50.3   87s
#   6380  5886 1.1687e+07  357   68 1.1739e+07 1.1687e+07  0.44%  52.4   92s
#   6733  6046 1.1687e+07  426   75 1.1739e+07 1.1687e+07  0.44%  56.3   99s
#   7056  6140 1.1687e+07  505   71 1.1739e+07 1.1687e+07  0.44%  60.1  104s
#   7316  6395 1.1687e+07  525    7 1.1739e+07 1.1687e+07  0.44%  66.0  110s
#   7702  6696 1.1687e+07  531    9 1.1739e+07 1.1687e+07  0.44%  70.7  116s
#   8172  6615 1.1687e+07  537    7 1.1739e+07 1.1687e+07  0.44%  73.6  123s
#
# Cutting planes:
#   Gomory: 1
#   Lift-and-project: 2
#   Implied bound: 276
#   Network: 1
#   Relax-and-lift: 9
#
# Explored 8276 nodes (642881 simplex iterations) in 123.40 seconds (153.71 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: 1.1739e+07 1.1739e+07 1.69465e+07 ... 2.53956e+07
#
# Solve interrupted
# Best objective 1.173903399648e+07, best bound 1.168728883771e+07, gap 0.4408%
#
# User-callback calls 21269, time in user-callback 0.13 sec
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Set parameter TimeLimit to value 10000
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1145G7 @ 2.60GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 165290 rows, 84593 columns and 10715628 nonzeros
# Model fingerprint: 0xbd737c1a
# Variable types: 0 continuous, 84593 integer (3897 binary)
# Coefficient statistics:
#   Matrix range     [1e-13, 9e+04]
#   Objective range  [2e+04, 2e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 8e+01]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 2.631776e+07
# Presolve removed 161393 rows and 19233 columns (presolve time = 6s) ...
# Presolve removed 164165 rows and 19233 columns
# Presolve time: 7.16s
# Presolved: 1125 rows, 65360 columns, 129747 nonzeros
# Variable types: 0 continuous, 65360 integer (1048 binary)
# Found heuristic solution: objective 2.631776e+07
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    7.5799861e+06   7.600000e+01   5.734500e+10      8s
#       80    2.1496201e+08   0.000000e+00   1.306033e+07      8s
#     7900    1.2655663e+07   0.000000e+00   0.000000e+00      8s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.265566e+07, 7900 iterations, 0.16 seconds (0.17 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.2656e+07    0   53 2.6318e+07 1.2656e+07  51.9%     -    7s
# H    0     0                    2.281124e+07 1.2656e+07  44.5%     -    7s
# H    0     0                    2.260824e+07 1.2656e+07  44.0%     -    7s
# H    0     0                    1.682592e+07 1.2656e+07  24.8%     -    7s
# H    0     0                    1.266124e+07 1.2656e+07  0.04%     -    9s
#      0     0 1.2656e+07    0   93 1.2661e+07 1.2656e+07  0.04%     -   10s
#      0     0 1.2656e+07    0   93 1.2661e+07 1.2656e+07  0.04%     -   10s
#      0     0 1.2656e+07    0   97 1.2661e+07 1.2656e+07  0.04%     -   10s
#      0     0 1.2656e+07    0  160 1.2661e+07 1.2656e+07  0.04%     -   10s
#      0     0 1.2656e+07    0  167 1.2661e+07 1.2656e+07  0.04%     -   10s
#      0     0 1.2656e+07    0  170 1.2661e+07 1.2656e+07  0.04%     -   11s
#      0     0 1.2656e+07    0  170 1.2661e+07 1.2656e+07  0.04%     -   11s
#      0     0 1.2656e+07    0   52 1.2661e+07 1.2656e+07  0.04%     -   12s
#      0     0 1.2656e+07    0   84 1.2661e+07 1.2656e+07  0.04%     -   13s
#      0     0 1.2656e+07    0  126 1.2661e+07 1.2656e+07  0.04%     -   13s
#      0     0 1.2656e+07    0  140 1.2661e+07 1.2656e+07  0.04%     -   14s
#      0     0 1.2656e+07    0  171 1.2661e+07 1.2656e+07  0.04%     -   14s
#      0     0 1.2656e+07    0  205 1.2661e+07 1.2656e+07  0.04%     -   14s
#      0     0 1.2656e+07    0  205 1.2661e+07 1.2656e+07  0.04%     -   14s
#      0     2 1.2656e+07    0  205 1.2661e+07 1.2656e+07  0.04%     -   15s
#    190   446 1.2656e+07   35  143 1.2661e+07 1.2656e+07  0.04%  21.9   21s
#    781  1442 1.2656e+07  170   90 1.2661e+07 1.2656e+07  0.04%  19.2   27s
#   2056  2426 1.2656e+07  465   31 1.2661e+07 1.2656e+07  0.04%  15.3   32s
#   2892  3307 1.2656e+07  637   29 1.2661e+07 1.2656e+07  0.04%  15.4   36s
#   3862  3604 1.2656e+07   16  108 1.2661e+07 1.2656e+07  0.04%  19.4   41s
#   4311  3924 1.2656e+07  635   52 1.2661e+07 1.2656e+07  0.04%  20.8   45s
#   4320  3930 1.2656e+07  798  284 1.2661e+07 1.2656e+07  0.04%  20.8   50s
#   4347  3953 1.2656e+07   14  166 1.2661e+07 1.2656e+07  0.04%  25.0   55s
#   4434  4052 1.2656e+07   25  268 1.2661e+07 1.2656e+07  0.04%  26.9   63s
#   4578  4371 1.2656e+07   38  152 1.2661e+07 1.2656e+07  0.04%  27.6   69s
#   4945  4491 1.2656e+07  105  143 1.2661e+07 1.2656e+07  0.04%  28.4   74s
#   5189  4644 1.2656e+07  138  212 1.2661e+07 1.2656e+07  0.04%  30.0   79s
#   5445  4861 1.2656e+07  187  194 1.2661e+07 1.2656e+07  0.04%  33.6   85s
#   5772  4973 1.2656e+07  243  197 1.2661e+07 1.2656e+07  0.04%  38.1   91s
#   6043  4921     cutoff  284      1.2661e+07 1.2656e+07  0.04%  41.7   95s
#   6167  5212 1.2656e+07  297   66 1.2661e+07 1.2656e+07  0.04%  47.9  102s
#   6571  5156 1.2656e+07  310   65 1.2661e+07 1.2656e+07  0.04%  50.6  110s
#   6732  5167 1.2656e+07  323   58 1.2661e+07 1.2656e+07  0.04%  54.6  115s
#   6933  5274 1.2656e+07  345   49 1.2661e+07 1.2656e+07  0.04%  61.1  122s
#
# Cutting planes:
#   Gomory: 11
#   Lift-and-project: 6
#   Implied bound: 413
#   MIR: 9
#   StrongCG: 2
#   Flow cover: 13
#   Zero half: 4
#   Relax-and-lift: 22
#
# Explored 7259 nodes (505651 simplex iterations) in 122.49 seconds (155.13 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 1.26612e+07 1.68259e+07 2.26082e+07 ... 2.63178e+07
#
# Solve interrupted
# Best objective 1.266123553996e+07, best bound 1.265566293549e+07, gap 0.0440%
#
# User-callback calls 19052, time in user-callback 0.08 sec
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Set parameter TimeLimit to value 10000
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1145G7 @ 2.60GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 165283 rows, 84586 columns and 10641629 nonzeros
# Model fingerprint: 0xda80e5a5
# Variable types: 0 continuous, 84586 integer (3890 binary)
# Coefficient statistics:
#   Matrix range     [1e-13, 9e+04]
#   Objective range  [2e+04, 2e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 8e+01]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 2.630186e+07
# Presolve removed 161393 rows and 19226 columns (presolve time = 7s) ...
# Presolve removed 164158 rows and 19226 columns
# Presolve time: 7.63s
# Presolved: 1125 rows, 65360 columns, 129747 nonzeros
# Variable types: 0 continuous, 65360 integer (1048 binary)
# Found heuristic solution: objective 2.630186e+07
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    7.5699861e+06   7.662500e+01   5.734500e+10      8s
#       79    2.1494611e+08   0.000000e+00   1.306033e+07      8s
#     7684    1.2638967e+07   0.000000e+00   0.000000e+00      8s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.263897e+07, 7684 iterations, 0.15 seconds (0.17 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.2639e+07    0   53 2.6302e+07 1.2639e+07  51.9%     -    8s
# H    0     0                    2.279534e+07 1.2639e+07  44.6%     -    8s
# H    0     0                    2.259234e+07 1.2639e+07  44.1%     -    8s
# H    0     0                    1.721602e+07 1.2639e+07  26.6%     -    8s
# H    0     0                    1.264534e+07 1.2639e+07  0.05%     -   11s
#      0     0 1.2639e+07    0   97 1.2645e+07 1.2639e+07  0.05%     -   11s
#      0     0 1.2639e+07    0   97 1.2645e+07 1.2639e+07  0.05%     -   11s
# H    0     0                    1.264534e+07 1.2639e+07  0.05%     -   12s
#      0     0 1.2639e+07    0   99 1.2645e+07 1.2639e+07  0.05%     -   12s
#      0     0 1.2639e+07    0  147 1.2645e+07 1.2639e+07  0.05%     -   12s
#      0     0 1.2639e+07    0  169 1.2645e+07 1.2639e+07  0.05%     -   12s
#      0     0 1.2639e+07    0  178 1.2645e+07 1.2639e+07  0.05%     -   12s
#      0     0 1.2639e+07    0  178 1.2645e+07 1.2639e+07  0.05%     -   13s
#      0     0 1.2639e+07    0   54 1.2645e+07 1.2639e+07  0.05%     -   14s
#      0     0 1.2639e+07    0  111 1.2645e+07 1.2639e+07  0.05%     -   17s
#      0     0 1.2639e+07    0  131 1.2645e+07 1.2639e+07  0.05%     -   20s
#      0     0 1.2639e+07    0  176 1.2645e+07 1.2639e+07  0.05%     -   20s
#      0     0 1.2639e+07    0  191 1.2645e+07 1.2639e+07  0.05%     -   20s
#      0     0 1.2639e+07    0  198 1.2645e+07 1.2639e+07  0.05%     -   21s
#      0     0 1.2639e+07    0  198 1.2645e+07 1.2639e+07  0.05%     -   21s
#      0     2 1.2639e+07    0  198 1.2645e+07 1.2639e+07  0.05%     -   23s
#      7    12 1.2639e+07    3  194 1.2645e+07 1.2639e+07  0.05%   127   25s
#     91   133 1.2639e+07   16  176 1.2645e+07 1.2639e+07  0.05%  52.3   32s
#    136   518 1.2639e+07   21  161 1.2645e+07 1.2639e+07  0.05%  59.6   38s
#    527  1192 1.2639e+07   93  103 1.2645e+07 1.2639e+07  0.05%  30.0   44s
#   1201  1472 1.2639e+07  314   47 1.2645e+07 1.2639e+07  0.05%  17.1   49s
#   1483  1773 1.2639e+07  388   21 1.2645e+07 1.2639e+07  0.05%  16.1   53s
#   1784  2243 1.2639e+07  469   36 1.2645e+07 1.2639e+07  0.05%  15.2   57s
#   2264  2666     cutoff  605      1.2645e+07 1.2639e+07  0.05%  14.8   61s
#   2697  3101 1.2639e+07    6  115 1.2645e+07 1.2639e+07  0.05%  14.8   65s
#   3409  3443 1.2639e+07   51  139 1.2645e+07 1.2639e+07  0.05%  17.0   71s
#   3839  3681 1.2639e+07  430   54 1.2645e+07 1.2639e+07  0.05%  20.3   75s
#   3855  3697 1.2639e+07   16  305 1.2645e+07 1.2639e+07  0.05%  24.7   80s
#   3916  3773 1.2639e+07   22  268 1.2645e+07 1.2639e+07  0.05%  26.0   85s
#   3957  3854 1.2639e+07   24  186 1.2645e+07 1.2639e+07  0.05%  26.4   91s
#   4054  4193 1.2639e+07   32  263 1.2645e+07 1.2639e+07  0.05%  27.5  103s
#   4451  4426 1.2639e+07   51  154 1.2645e+07 1.2639e+07  0.05%  30.7  113s
#   4849  4552 1.2639e+07   78  265 1.2645e+07 1.2639e+07  0.05%  33.7  122s
#
# Cutting planes:
#   Gomory: 7
#   Lift-and-project: 4
#   Implied bound: 430
#   MIR: 39
#   StrongCG: 6
#   Flow cover: 15
#   Zero half: 1
#   Relax-and-lift: 26
#
# Explored 5115 nodes (207348 simplex iterations) in 123.12 seconds (106.17 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: 1.26453e+07 1.26453e+07 1.7216e+07 ... 2.63019e+07
#
# Solve interrupted
# Best objective 1.264533561976e+07, best bound 1.263896694837e+07, gap 0.0504%
#
# User-callback calls 14262, time in user-callback 0.16 sec
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Set parameter TimeLimit to value 10000
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1145G7 @ 2.60GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 165696 rows, 84999 columns and 13556683 nonzeros
# Model fingerprint: 0xbbf9217b
# Variable types: 0 continuous, 84999 integer (4303 binary)
# Coefficient statistics:
#   Matrix range     [1e-13, 9e+04]
#   Objective range  [2e+04, 2e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 8e+01]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 2.763747e+07
# Presolve removed 161393 rows and 19639 columns (presolve time = 22s) ...
# Presolve removed 164571 rows and 19639 columns
# Presolve time: 24.67s
# Presolved: 1125 rows, 65360 columns, 129747 nonzeros
# Variable types: 0 continuous, 65360 integer (1048 binary)
# Found heuristic solution: objective 2.763747e+07
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    8.4099846e+06   8.812500e+01   5.734500e+10     26s
#       80    2.1628171e+08   0.000000e+00   1.306033e+07     26s
#     8192    1.4041441e+07   0.000000e+00   0.000000e+00     26s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.404144e+07, 8192 iterations, 0.39 seconds (0.17 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.4041e+07    0   49 2.7637e+07 1.4041e+07  49.2%     -   26s
# H    0     0                    2.331894e+07 1.4041e+07  39.8%     -   26s
# H    0     0                    2.311594e+07 1.4041e+07  39.3%     -   26s
# H    0     0                    1.855162e+07 1.4041e+07  24.3%     -   26s
# H    0     0                    1.418394e+07 1.4041e+07  1.00%     -   29s
#      0     0 1.4041e+07    0   86 1.4184e+07 1.4041e+07  1.00%     -   30s
# H    0     0                    1.418394e+07 1.4041e+07  1.00%     -   32s
#      0     0 1.4041e+07    0   90 1.4184e+07 1.4041e+07  1.00%     -   32s
#      0     0 1.4041e+07    0  149 1.4184e+07 1.4041e+07  1.00%     -   33s
#      0     0 1.4041e+07    0  137 1.4184e+07 1.4041e+07  1.00%     -   33s
#      0     0 1.4041e+07    0  177 1.4184e+07 1.4041e+07  1.00%     -   33s
#      0     0 1.4041e+07    0  177 1.4184e+07 1.4041e+07  1.00%     -   33s
#      0     2 1.4041e+07    0  176 1.4184e+07 1.4041e+07  1.00%     -   37s
#     27    32 1.4041e+07    7  161 1.4184e+07 1.4041e+07  1.00%  86.4   41s
#     97   231 1.4041e+07   20  142 1.4184e+07 1.4041e+07  1.00%  36.9   47s
#    230   738 1.4041e+07   52  111 1.4184e+07 1.4041e+07  1.00%  29.1   53s
#    737  1066 1.4041e+07  199   30 1.4184e+07 1.4041e+07  1.00%  35.9   59s
#   1065  1577 1.4041e+07  310   24 1.4184e+07 1.4041e+07  1.00%  35.9   64s
#   1576  1733 1.4041e+07  424   25 1.4184e+07 1.4041e+07  1.00%  34.5   69s
# H 1577  1733                    1.413478e+07 1.4041e+07  0.66%  34.4   69s
#   1732  2213 1.4041e+07  473   19 1.4135e+07 1.4041e+07  0.66%  34.6   74s
# H 2212  2620                    1.413478e+07 1.4041e+07  0.66%  31.8   80s
# H 2330  2620                    1.413478e+07 1.4041e+07  0.66%  30.3   80s
# H 2331  2620                    1.413478e+07 1.4041e+07  0.66%  30.3   80s
# H 2619  3131                    1.413478e+07 1.4041e+07  0.66%  27.8   88s
# H 2619  3131                    1.413478e+07 1.4041e+07  0.66%  27.8   88s
# H 3130  4083                    1.413478e+07 1.4041e+07  0.66%  24.6   93s
#   4088  4625 1.4041e+07  950    4 1.4135e+07 1.4041e+07  0.66%  20.8   98s
# H 4441  4625                    1.413478e+07 1.4041e+07  0.66%  20.4   98s
# H 4668  4933                    1.413478e+07 1.4041e+07  0.66%  20.4  102s
# H 4841  4933                    1.413478e+07 1.4041e+07  0.66%  20.8  102s
# H 4914  4933                    1.413478e+07 1.4041e+07  0.66%  21.7  102s
#   4979  4935 1.4041e+07  524   56 1.4135e+07 1.4041e+07  0.66%  22.4  106s
# H 4980  4689                    1.413478e+07 1.4041e+07  0.66%  22.4  108s
#   4982  4690 1.4041e+07   78  181 1.4135e+07 1.4041e+07  0.66%  22.4  110s
# H 4984  4457                    1.413478e+07 1.4041e+07  0.66%  22.4  112s
#   4987  4459 1.4041e+07  846  267 1.4135e+07 1.4041e+07  0.66%  22.4  116s
#   4988  4459 1.4041e+07  150  267 1.4135e+07 1.4041e+07  0.66%  22.4  120s
#
# Cutting planes:
#   Gomory: 2
#   Lift-and-project: 4
#   Implied bound: 264
#   MIR: 7
#   Flow cover: 48
#   Zero half: 9
#   Relax-and-lift: 32
#
# Explored 4988 nodes (140286 simplex iterations) in 120.86 seconds (65.51 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 1.41348e+07 1.41348e+07 1.41348e+07 ... 1.41348e+07
#
# Solve interrupted
# Best objective 1.413477884673e+07, best bound 1.404144073184e+07, gap 0.6603%
#
# User-callback calls 13739, time in user-callback 0.08 sec
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Set parameter TimeLimit to value 10000
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1145G7 @ 2.60GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 165297 rows, 84600 columns and 10806936 nonzeros
# Model fingerprint: 0xd2f56816
# Variable types: 0 continuous, 84600 integer (3904 binary)
# Coefficient statistics:
#   Matrix range     [1e-13, 9e+04]
#   Objective range  [2e+04, 2e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 8e+01]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 2.633366e+07
# Presolve removed 161393 rows and 19240 columns (presolve time = 15s) ...
# Presolve removed 164172 rows and 19240 columns (presolve time = 16s) ...
# Presolve removed 164172 rows and 19240 columns
# Presolve time: 16.59s
# Presolved: 1125 rows, 65360 columns, 129747 nonzeros
# Variable types: 0 continuous, 65360 integer (1048 binary)
# Found heuristic solution: objective 2.633366e+07
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    7.5899861e+06   7.937500e+01   5.734500e+10     18s
#       80    2.1497791e+08   0.000000e+00   1.306033e+07     18s
#     7779    1.2672359e+07   0.000000e+00   0.000000e+00     18s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.267236e+07, 7779 iterations, 0.39 seconds (0.17 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.2672e+07    0   49 2.6334e+07 1.2672e+07  51.9%     -   17s
# H    0     0                    2.201514e+07 1.2672e+07  42.4%     -   17s
# H    0     0                    1.704482e+07 1.2672e+07  25.7%     -   18s
# H    0     0                    1.267714e+07 1.2672e+07  0.04%     -   22s
#      0     0 1.2672e+07    0   91 1.2677e+07 1.2672e+07  0.04%     -   23s
#      0     0 1.2672e+07    0   91 1.2677e+07 1.2672e+07  0.04%     -   23s
# H    0     0                    1.267714e+07 1.2672e+07  0.04%     -   25s
#      0     0 1.2672e+07    0   95 1.2677e+07 1.2672e+07  0.04%     -   25s
#      0     0 1.2672e+07    0  148 1.2677e+07 1.2672e+07  0.04%     -   25s
#      0     0 1.2672e+07    0  153 1.2677e+07 1.2672e+07  0.04%     -   25s
# ...
# H 4564  4858                    1.392808e+07 1.3824e+07  0.74%  21.1  106s
# H 4647  4858                    1.392808e+07 1.3824e+07  0.74%  21.9  106s
#   4903  4861 1.3824e+07  322  108 1.3928e+07 1.3824e+07  0.74%  22.4  112s
#   4906  4863 1.3824e+07  381  174 1.3928e+07 1.3824e+07  0.74%  22.4  115s
#   4911  4866 1.3824e+07  113  243 1.3928e+07 1.3824e+07  0.74%  22.3  123s
#
# Cutting planes:
#   Gomory: 1
#   Lift-and-project: 6
#   Implied bound: 362
#   MIR: 5
#   Flow cover: 1
#   Zero half: 6
#   Network: 1
#   Relax-and-lift: 9
#
# Explored 4911 nodes (139621 simplex iterations) in 123.35 seconds (61.86 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 1.39281e+07 1.39281e+07 1.39281e+07 ... 1.39281e+07
#
# Solve interrupted
# Best objective 1.392807864549e+07, best bound 1.382439153681e+07, gap 0.7444%
#
# User-callback calls 13814, time in user-callback 0.04 sec
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Set parameter TimeLimit to value 10000
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1145G7 @ 2.60GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 165465 rows, 84768 columns and 11899285 nonzeros
# Model fingerprint: 0x9a0f8142
# Variable types: 0 continuous, 84768 integer (4072 binary)
# Coefficient statistics:
#   Matrix range     [1e-13, 9e+04]
#   Objective range  [2e+04, 2e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 8e+01]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 2.693787e+07
# Presolve removed 161393 rows and 19408 columns (presolve time = 17s) ...
# Presolve removed 164340 rows and 19408 columns
# Presolve time: 18.97s
# Presolved: 1125 rows, 65360 columns, 129747 nonzeros
# Variable types: 0 continuous, 65360 integer (1048 binary)
# Found heuristic solution: objective 2.693787e+07
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    7.9699854e+06   8.225000e+01   5.734500e+10     20s
#       77    2.1558211e+08   0.000000e+00   1.306031e+07     20s
#     7932    1.3306812e+07   0.000000e+00   0.000000e+00     20s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.330681e+07, 7932 iterations, 0.36 seconds (0.17 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.3307e+07    0   54 2.6938e+07 1.3307e+07  50.6%     -   20s
# H    0     0                    2.363434e+07 1.3307e+07  43.7%     -   20s
# H    0     0                    2.343134e+07 1.3307e+07  43.2%     -   20s
# H    0     0                    1.777510e+07 1.3307e+07  25.1%     -   20s
# H    0     0                    1.348434e+07 1.3307e+07  1.32%     -   24s
# H    0     0                    1.348434e+07 1.3307e+07  1.32%     -   24s
# H    0     0                    1.335826e+07 1.3307e+07  0.39%     -   24s
#      0     0 1.3307e+07    0   96 1.3358e+07 1.3307e+07  0.39%     -   24s
# H    0     0                    1.335826e+07 1.3307e+07  0.39%     -   26s
#      0     0 1.3307e+07    0  100 1.3358e+07 1.3307e+07  0.39%     -   26s
#      0     0 1.3307e+07    0  167 1.3358e+07 1.3307e+07  0.39%     -   27s
#      0     0 1.3307e+07    0  173 1.3358e+07 1.3307e+07  0.39%     -   27s
#      0     0 1.3307e+07    0  174 1.3358e+07 1.3307e+07  0.39%     -   27s
#      0     0 1.3307e+07    0  174 1.3358e+07 1.3307e+07  0.39%     -   28s
#      0     2 1.3307e+07    0  174 1.3358e+07 1.3307e+07  0.39%     -   31s
#     31    51 1.3307e+07    8  178 1.3358e+07 1.3307e+07  0.39%  81.9   35s
#    265   727 1.3307e+07   36  132 1.3358e+07 1.3307e+07  0.39%  37.4   45s
#    726  1147 1.3307e+07  177   59 1.3358e+07 1.3307e+07  0.39%  23.7   53s
#   1170  1575 1.3307e+07  381   38 1.3358e+07 1.3307e+07  0.39%  18.6   58s
#   1600  2195 1.3307e+07  491   20 1.3358e+07 1.3307e+07  0.39%  18.1   62s
#   2221  2591 1.3307e+07  676   20 1.3358e+07 1.3307e+07  0.39%  17.6   66s
#   2617  3005 1.3307e+07  783   15 1.3358e+07 1.3307e+07  0.39%  17.5   71s
#   3638  3788 1.3307e+07    5  153 1.3358e+07 1.3307e+07  0.39%  18.0   78s
#   3846  4141 1.3307e+07   23   79 1.3358e+07 1.3307e+07  0.39%  18.2   81s
# H 4141  4141                    1.335826e+07 1.3307e+07  0.39%  19.7   81s
#   4199  4736 1.3307e+07   65  108 1.3358e+07 1.3307e+07  0.39%  20.5   85s
#   4802  5215 1.3307e+07  109  107 1.3358e+07 1.3307e+07  0.39%  22.8   95s
#   5291  5218 1.3307e+07   79   94 1.3358e+07 1.3307e+07  0.39%  24.8  101s
#   5295  5221 1.3307e+07  514  236 1.3358e+07 1.3307e+07  0.39%  24.8  105s
#   5300  5224 1.3307e+07  157  289 1.3358e+07 1.3307e+07  0.39%  24.8  111s
#   5304  5232 1.3307e+07   14  257 1.3358e+07 1.3307e+07  0.39%  28.7  115s
#   5328  5248 1.3307e+07   17  205 1.3358e+07 1.3307e+07  0.39%  29.4  120s
#
# Cutting planes:
#   Gomory: 6
#   Lift-and-project: 14
#   Implied bound: 397
#   MIR: 62
#   StrongCG: 13
#   Flow cover: 50
#   Zero half: 7
#   Network: 1
#   Relax-and-lift: 49
#
# Explored 5332 nodes (165522 simplex iterations) in 120.50 seconds (65.56 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 1.33583e+07 1.33583e+07 1.33583e+07 ... 2.69379e+07
#
# Solve interrupted
# Best objective 1.335825736670e+07, best bound 1.330681177239e+07, gap 0.3851%
#
# User-callback calls 14630, time in user-callback 0.13 sec
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Set parameter TimeLimit to value 10000
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1145G7 @ 2.60GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 165402 rows, 84705 columns and 11470186 nonzeros
# Model fingerprint: 0x9d6684ae
# Variable types: 0 continuous, 84705 integer (4009 binary)
# Coefficient statistics:
#   Matrix range     [1e-13, 9e+04]
#   Objective range  [2e+04, 2e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 8e+01]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 2.671526e+07
# Presolve removed 161393 rows and 19345 columns (presolve time = 16s) ...
# Presolve removed 164277 rows and 19345 columns
# Presolve time: 18.25s
# Presolved: 1125 rows, 65360 columns, 129747 nonzeros
# Variable types: 0 continuous, 65360 integer (1048 binary)
# Found heuristic solution: objective 2.671526e+07
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    7.8299857e+06   8.125000e+01   5.734500e+10     20s
#       77    2.1535951e+08   0.000000e+00   1.306054e+07     20s
#     8118    1.3073066e+07   0.000000e+00   0.000000e+00     20s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.307307e+07, 8118 iterations, 0.43 seconds (0.17 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.3073e+07    0   55 2.6715e+07 1.3073e+07  51.1%     -   19s
# H    0     0                    2.361474e+07 1.3073e+07  44.6%     -   19s
# H    0     0                    1.790934e+07 1.3073e+07  27.0%     -   19s
# H    0     0                    1.326174e+07 1.3073e+07  1.42%     -   22s
# H    0     0                    1.326174e+07 1.3073e+07  1.42%     -   23s
#      0     0 1.3073e+07    0  105 1.3262e+07 1.3073e+07  1.42%     -   23s
#      0     0 1.3073e+07    0  107 1.3262e+07 1.3073e+07  1.42%     -   25s
#      0     0 1.3073e+07    0  155 1.3262e+07 1.3073e+07  1.42%     -   26s
#      0     0 1.3073e+07    0  160 1.3262e+07 1.3073e+07  1.42%     -   26s
#      0     0 1.3073e+07    0  177 1.3262e+07 1.3073e+07  1.42%     -   26s
#      0     0 1.3073e+07    0  177 1.3262e+07 1.3073e+07  1.42%     -   27s
#      0     2 1.3073e+07    0  177 1.3262e+07 1.3073e+07  1.42%     -   28s
#     19    24 1.3073e+07    6  184 1.3262e+07 1.3073e+07  1.42%  59.9   30s
#    120   286 1.3073e+07   20  144 1.3262e+07 1.3073e+07  1.42%  36.3   37s
#    285   723 1.3073e+07   46  127 1.3262e+07 1.3073e+07  1.42%  32.8   43s
# H  446   723                    1.313566e+07 1.3073e+07  0.48%  36.1   43s
# H  722  1014                    1.313566e+07 1.3073e+07  0.48%  26.0   48s
#   1015  1310 1.3073e+07  180  117 1.3136e+07 1.3073e+07  0.48%  24.5   54s
# H 1016  1310                    1.313566e+07 1.3073e+07  0.48%  24.5   54s
#   1336  1710 1.3073e+07  181  118 1.3136e+07 1.3073e+07  0.48%  21.5   59s
#   1759  2128 1.3073e+07  243  117 1.3136e+07 1.3073e+07  0.48%  21.1   64s
#   2182  2762 1.3073e+07  293  120 1.3136e+07 1.3073e+07  0.48%  22.6   69s
#   2823  3179 1.3073e+07  411  111 1.3136e+07 1.3073e+07  0.48%  24.1   74s
#   3253  3818 1.3073e+07  545   21 1.3136e+07 1.3073e+07  0.48%  22.8   79s
#   3905  4542 1.3073e+07  826   27 1.3136e+07 1.3073e+07  0.48%  24.2   84s
#   4643  5296 1.3073e+07    8  125 1.3136e+07 1.3073e+07  0.48%  22.3   89s
#   5421  5297 1.3114e+07 1059  177 1.3136e+07 1.3073e+07  0.48%  21.9   91s
#   5423  5298 1.3073e+07  315   49 1.3136e+07 1.3073e+07  0.48%  21.9   98s
#   5424  5299 1.3073e+07  214   97 1.3136e+07 1.3073e+07  0.48%  21.9  101s
# H 5424  5034                    1.313566e+07 1.3073e+07  0.48%  21.9  103s
#   5426  5035 1.3073e+07   56  193 1.3136e+07 1.3073e+07  0.48%  21.9  105s
#   5428  5037 1.3073e+07  133  252 1.3136e+07 1.3073e+07  0.48%  21.9  110s
#   5432  5039 1.3073e+07   37  388 1.3136e+07 1.3073e+07  0.48%  21.9  116s
#   5433  5040 1.3073e+07  482  388 1.3136e+07 1.3073e+07  0.48%  21.9  120s
#
# Cutting planes:
#   Gomory: 4
#   Lift-and-project: 5
#   Implied bound: 338
#   MIR: 42
#   StrongCG: 5
#   Flow cover: 117
#   Zero half: 7
#   Network: 1
#   Relax-and-lift: 55
#
# Explored 5433 nodes (149967 simplex iterations) in 120.28 seconds (61.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 1.31357e+07 1.31357e+07 1.31357e+07 ... 2.67153e+07
#
# Solve interrupted
# Best objective 1.313565673385e+07, best bound 1.307306611987e+07, gap 0.4765%
#
# User-callback calls 14651, time in user-callback 0.12 sec
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Set parameter TimeLimit to value 10000
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1145G7 @ 2.60GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 165563 rows, 84866 columns and 12592267 nonzeros
# Model fingerprint: 0xb1cf01dd
# Variable types: 0 continuous, 84866 integer (4170 binary)
# Coefficient statistics:
#   Matrix range     [1e-13, 9e+04]
#   Objective range  [2e+04, 2e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 8e+01]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 2.714457e+07
# Presolve removed 161393 rows and 19506 columns (presolve time = 19s) ...
# Presolve removed 164438 rows and 19506 columns (presolve time = 20s) ...
# Presolve removed 164438 rows and 19506 columns
# Presolve time: 21.41s
# Presolved: 1125 rows, 65360 columns, 129747 nonzeros
# Variable types: 0 continuous, 65360 integer (1048 binary)
# Found heuristic solution: objective 2.714457e+07
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    8.0999851e+06   8.350000e+01   5.734500e+10     23s
#       80    2.1578881e+08   0.000000e+00   1.306033e+07     23s
#     7817    1.3523861e+07   0.000000e+00   0.000000e+00     23s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.352386e+07, 7817 iterations, 0.37 seconds (0.17 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.3524e+07    0   50 2.7145e+07 1.3524e+07  50.2%     -   22s
# H    0     0                    2.302904e+07 1.3524e+07  41.3%     -   22s
# H    0     0                    2.282604e+07 1.3524e+07  40.8%     -   22s
# H    0     0                    1.922756e+07 1.3524e+07  29.7%     -   23s
# H    0     0                    1.369104e+07 1.3524e+07  1.22%     -   26s
# H    0     0                    1.369104e+07 1.3524e+07  1.22%     -   27s
#      0     0 1.3524e+07    0  102 1.3691e+07 1.3524e+07  1.22%     -   27s
#      0     0 1.3524e+07    0  102 1.3691e+07 1.3524e+07  1.22%     -   29s
#      0     0 1.3524e+07    0  161 1.3691e+07 1.3524e+07  1.22%     -   30s
#      0     0 1.3524e+07    0  155 1.3691e+07 1.3524e+07  1.22%     -   30s
#      0     0 1.3524e+07    0  184 1.3691e+07 1.3524e+07  1.22%     -   30s
#      0     0 1.3524e+07    0  184 1.3691e+07 1.3524e+07  1.22%     -   31s
#      0     2 1.3524e+07    0  184 1.3691e+07 1.3524e+07  1.22%     -   34s
#      7    12 1.3524e+07    3  168 1.3691e+07 1.3524e+07  1.22%  67.3   35s
# H   27    32                    1.369104e+07 1.3524e+07  1.22%  59.8   37s
# H   28    32                    1.369104e+07 1.3524e+07  1.22%  58.4   37s
# H   29    32                    1.369104e+07 1.3524e+07  1.22%  56.8   37s
# H   30    32                    1.356496e+07 1.3524e+07  0.30%  55.1   37s
#    124   337 1.3524e+07   22  150 1.3565e+07 1.3524e+07  0.30%  30.3   43s
#    336   437 1.3524e+07   63   86 1.3565e+07 1.3524e+07  0.30%  26.8   50s
# H  368   437                    1.356496e+07 1.3524e+07  0.30%  27.3   50s
# H  369   437                    1.356496e+07 1.3524e+07  0.30%  27.4   50s
# H  372   437                    1.356496e+07 1.3524e+07  0.30%  27.2   50s
#    436   975 1.3524e+07   95   87 1.3565e+07 1.3524e+07  0.30%  25.0   56s
#    980  1240 1.3524e+07  180   94 1.3565e+07 1.3524e+07  0.30%  25.8   64s
# H 1156  1240                    1.356496e+07 1.3524e+07  0.30%  26.0   64s
#   1263  1909 1.3524e+07  264   87 1.3565e+07 1.3524e+07  0.30%  25.2   69s
#   1942  2368 1.3524e+07  369   84 1.3565e+07 1.3524e+07  0.30%  22.3   74s
# H 1975  2368                    1.356496e+07 1.3524e+07  0.30%  22.4   74s
#   2402  2977 1.3524e+07  433   86 1.3565e+07 1.3524e+07  0.30%  22.0   78s
#   3018  3708 1.3524e+07  524   38 1.3565e+07 1.3524e+07  0.30%  20.4   82s
#   3754  4043 1.3524e+07  851    5 1.3565e+07 1.3524e+07  0.30%  19.2   89s
#   4098  4310 1.3524e+07    8  141 1.3565e+07 1.3524e+07  0.30%  18.4   92s
#   4372  4901 1.3524e+07   74    4 1.3565e+07 1.3524e+07  0.30%  20.0   97s
#   4974  4903 1.3524e+07  704   55 1.3565e+07 1.3524e+07  0.30%  20.1  102s
#   4975  4904 1.3524e+07  622  115 1.3565e+07 1.3524e+07  0.30%  20.1  105s
#   4981  4908 1.3524e+07  398  246 1.3565e+07 1.3524e+07  0.30%  20.0  110s
#   4983  4909 1.3524e+07  650  246 1.3565e+07 1.3524e+07  0.30%  20.0  115s
#   5019  4944 1.3524e+07   20  284 1.3565e+07 1.3524e+07  0.30%  24.7  120s
#
# Cutting planes:
#   Gomory: 5
#   Lift-and-project: 4
#   Implied bound: 381
#   MIR: 6
#   StrongCG: 2
#   Flow cover: 40
#   Zero half: 4
#   Relax-and-lift: 23
#
# Explored 5029 nodes (132501 simplex iterations) in 120.34 seconds (62.90 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 1.3565e+07 1.3565e+07 1.3565e+07 ... 1.3691e+07
#
# Solve interrupted
# Best objective 1.356495749911e+07, best bound 1.352386096231e+07, gap 0.3030%
#
# User-callback calls 13359, time in user-callback 0.06 sec

# %%
total_drones.to_csv('5100 0.97.csv', index=False)

# %% [markdown]
# Probabilistic model

# %% [markdown]
# Probabilistic model with relaxed constraints

# %%
#Redefine set L
L = list()
for k, j in itertools.product(K.index, J.index):
    if dist_KJ[(k, j)] <= B:
        L.append((k, j))
        

#Redefine set P
P = list()
for i, k in itertools.product(I.index, K.index):
    if dist_IK[(i, k)] <= B:
        P.append((i, k))

#Redefine sets M_kj

M_kj = {}
M_interim = []

for (k, j) in L:
    for i in I.index:
        if dist_JI[j, i] <= S:
            if dist_JI[j, i] + dist_IK[i, k] <= B:
                M_interim.append(i)
    M_kj[(k, j)] = M_interim
    M_interim = []

M_kj_final = {key : val for key, val in M_kj.items() if val != []}  

KJ_feas = list(M_kj_final.keys())


#Redefine sets N_i

N_i = {}
N_interim = []

for i in I.index:
    for (k, j) in L:
        if dist_JI[j, i] <= S:
            if dist_JI[j, i] + dist_IK[i, k] <= B:
                N_interim.append((k, j))
    N_i[i] = N_interim
    N_interim = []
    
N_i_final = {key : val for key, val in N_i.items() if val != []}   
 
I_feas = list(N_i_final.keys())


#Redefine sets O_j

O_j = {}
O_interim = []

for j in J.index:
    for (i, k) in P:
        if dist_JI[j, i] <= S:
            if dist_JI[j, i] + dist_IK[i, k] <= B:
                O_interim.append((i, k))
    O_j[j] = O_interim
    O_interim = []
    
O_j_final = {key : val for key, val in O_j.items() if val != []}   
 
J_feas = list(O_j_final.keys())

# %%
model_prob_rel = gp.Model('Probabilistic model with relaxation')

x_ikj = model_prob_rel.addVars(I.index, L, vtype = GRB.INTEGER, name = 'x_ikj')
y_j = model_prob_rel.addVars(J.index, vtype = GRB.BINARY, name = 'y_j')
z_ig = model_prob_rel.addVars(IG, vtype = GRB.BINARY, name = 'z_ig')

model_prob_rel.addConstr((gp.quicksum(h_ig[ig] * z_ig[ig] for ig in I_feasG)) >= phi, name = 'c15')
model_prob_rel.addConstrs((gp.quicksum(x_ikj[i, k, j] for (k, j) in N_i_final[i]) == l_i[i] + gp.quicksum(z_ig) for (i, g) in I_feasG), name = 'c16')

model_prob_rel.addConstrs((gp.quicksum(x_ikj[i, k, j] for (i, k) in O_j_final[j]) <= q_j[j] * y_j[j] for j in J_feas), name = 'c4')
model_prob_rel.addConstrs(((dist_JI[(j, i)] + dist_IK[(i, k)]) * x_ikj[i, k, j] <= B * x_ikj[i, k, j]
                  for i in I_feas for (k, j) in KJ_feas), name = 'c5')
model_prob_rel.addConstrs((dist_JI[(j, i)] * x_ikj[i, k, j] <= S * x_ikj[i, k, j] for i in I_feas for (k, j) in KJ_feas), name = 'c6')
model_prob_rel.addConstrs((y_j[k] == 1 for k in K.index), name = 'c7')


model_prob_rel.setObjective(gp.quicksum(alpha * x_ikj[i, k, j] + gamma * (dist_JI[(j, i)] + dist_IK[(i, k)] + dist_KJ[(k, j)]) * x_ikj[i, k, j] for i in I_feas for (k, j) in KJ_feas) + gp.quicksum(beta[j] * y_j[j] for j in J_feas), GRB.MINIMIZE)
model_prob_rel.setParam('TimeLimit', hardlimit)
model_prob_rel.optimize(softtime)

# %% [markdown]
# Deterministic model with relaxed constraints

# %%
model_det_rel = gp.Model('Deterministic model with relaxation')

x_ikj = model_det_rel.addVars(I.index, L, vtype = GRB.INTEGER, name = 'x_ikj')
y_j = model_det_rel.addVars(J.index, vtype = GRB.BINARY, name = 'y_j')

model_det_rel.addConstrs((gp.quicksum(x_ikj[i, k, j] for (k, j) in N_i_final[i]) >= theta_det[i] for i in I_feas), name = 'c2')

model_det_rel.addConstrs((gp.quicksum(x_ikj[i, k, j] for (i, k) in O_j_final[j]) <= q_j[j] * y_j[j] for j in J_feas), name = 'c4')
model_det_rel.addConstrs(((dist_JI[(j, i)] + dist_IK[(i, k)]) * x_ikj[i, k, j] <= B * x_ikj[i, k, j]
                  for i in I_feas for (k, j) in KJ_feas), name = 'c5')
model_det_rel.addConstrs((dist_JI[(j, i)] * x_ikj[i, k, j] <= S * x_ikj[i, k, j] for i in I_feas for (k, j) in KJ_feas), name = 'c6')
model_det_rel.addConstrs((y_j[k] == 1 for k in K.index), name = 'c7')

model_det_rel.setObjective(gp.quicksum(alpha * x_ikj[i, k, j] + gamma * (dist_JI[(j, i)] + dist_IK[(i, k)] + dist_KJ[(k, j)]) * x_ikj[i, k, j] for i in I_feas for (k, j) in KJ_feas) + gp.quicksum(beta[j] * y_j[j] for j in J_feas), GRB.MINIMIZE)
model_det_rel.setParam('TimeLimit', hardlimit)
model_det_rel.optimize(softtime)

# %% [markdown]
# 1) complete information optimum - lower bound for optimum
# 2) price of uncertainty

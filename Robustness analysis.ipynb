# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import itertools
import random
from scipy.stats import poisson

#%pip install gurobipy
import gurobipy as gp
from gurobipy import GRB

# %% [markdown]
# Data generation

# %%
### PASSAU  ###

#Define sets of I, J, K, where J contains I and K for Passau

#Define the number of elements in each set I, J, K

degree_to_m = 111111

#Define empty data frames
I_coordinates = pd.DataFrame(columns = ['Point number', 'Latitude', 'Longitude'])
J_coordinates = pd.DataFrame(columns = ['Point number', 'Latitude', 'Longitude'])
K_coordinates = pd.DataFrame(columns = ['Point number', 'Latitude', 'Longitude'])

column_types = {
    'Name': 'str',  # Example: 'int', 'float', 'str', 'datetime64[ns]', etc.
    'Latitude': 'float',
    'Longitude': 'float',
    'Address': 'str'
    # Add more columns and their data types as needed
}

doctors = pd.read_csv('Doctors coordinates.txt', sep = ';', index_col = False, dtype=column_types)

doctors

for i in range(len(doctors['Latitude'])):
    I_coordinates.loc[i, 'Point number'] = 'i'+ str(i)
    I_coordinates.loc[i, 'Latitude'] = doctors.loc[i, 'Latitude']
    I_coordinates.loc[i, 'Longitude'] = doctors.loc[i, 'Longitude']

I_coordinates.index = I_coordinates['Point number']

I = I_coordinates * degree_to_m
I['Point number'] = I_coordinates['Point number']


labs = pd.read_csv('Labs coordinates.txt', sep = ';', index_col = False, dtype=column_types) 
labs

for k in range(len(labs['Latitude'])):
    K_coordinates.loc[k, 'Point number'] = 'k'+ str(k)
    K_coordinates.loc[k, 'Latitude'] = labs.loc[k, 'Latitude']
    K_coordinates.loc[k, 'Longitude'] = labs.loc[k, 'Longitude']

K_coordinates.index = K_coordinates['Point number']

K = K_coordinates * degree_to_m
K['Point number'] = K_coordinates['Point number']


#Define range of coordinates

combined_coordinates = pd.concat([I_coordinates, K_coordinates])

min_latitude = combined_coordinates['Latitude'].min()
max_latitude = combined_coordinates['Latitude'].max()
min_longitude = combined_coordinates['Longitude'].min()
max_longitude = combined_coordinates['Longitude'].max()

grid_spacing = 0.0018

# Create grid points
grid_points = []
for lat in np.arange(min_latitude, max_latitude + grid_spacing, grid_spacing):
    for lon in np.arange(min_longitude, max_longitude + grid_spacing, grid_spacing):
        grid_points.append((round(lat, 6), round(lon, 6)))

J_coordinates = pd.DataFrame(grid_points, columns=['Latitude', 'Longitude'])
J_coordinates['Point number'] = ['j' + str(i) for i in range(len(J_coordinates))]

J_coordinates.index = J_coordinates['Point number'] 
J_coordinates = pd.concat([J_coordinates, K_coordinates, I_coordinates], axis = 0) #Include K to J

river = ['j972', 'j973', 'j918', 'j919', 'j920', 'j866', 'j867', 'j813', 'j814',
'j815', 'j760', 'j761', 'j762', 'j707', 'j708', 'j709', 'j710', 'j654',
'j655', 'j656', 'j657', 'j658', 'j606', 'j610', 'j611', 'j612', 'j613', 'j614',
'j615', 'j616', 'j620', 'j621', 'j622', 'j623', 'j624', 'j625', 'j682', 'j683',
'j684','j685','j686', 'j635', 'j636', 'j637', 'j638', 'j585', 'j586', 'j587', 
'j588', 'j589', 'j590', 'j591', 'j592','j593', 'j531', 'j530', 'j529', 'j528',
'j527', 'j22', 'j23', 'j77', 'j132', 'j133', 'j134', 'j189', 'j190', 'j244',
'j245', 'j300', 'j301', 'j356', 'j411', 'j412', 'j467', 'j523', 'j524', 'j525', 'j526',

'j246', 'j247', 'j191', 'j192', 'j193', 'j194', 'j135', 'j136', 'j137', 'j138', 'j139',
'j140', 'j141', 'j78', 'j79', 'j80', 'j81', 'j82', 'j83', 'j84', 'j85', 'j86', 'j87', 'j88',
'j24', 'j25', 'j26', 'j27', 'j28', 'j29', 'j30', 'j31', 'j32', 'j33', 'j34', 'j35', 'j36',
 'j261', 'j262', 'j263', 'j264', 'j266', 'j267', 'j268', 'j269', 'j206', 'j207', 'j208',
'j209', 'j210', 'j211', 'j212', 'j213', 'j214', 'j215', 'j153', 'j154', 'j155', 'j156',
'j157', 'j158', 'j159', 'j160', 'j161', 'j98', 'j99', 'j100', 'j101', 'j102', 'j103', 
'j104', 'j105', 'j106', 'j107', 'j43', 'j44', 'j45', 'j46', 'j47', 'j48', 'j49', 'j50', 
'j51', 'j52', 'j53'
 ]

J_coordinates = J_coordinates.drop(index = river) #excluding locations on the river

J = J_coordinates * degree_to_m
J['Point number'] = J_coordinates['Point number']

# %%
#Define constants

B = 91800 #battery load: meters of travel
S = 5100 #meters of service time

p = 0.999

alpha = 15900 #euro

beta = {}
for j in J.index:
    if j.startswith('j'):
        beta[j] = 203000
    else:
        beta[j] = 76920
        
gamma = 0.0045 / 1000 # variable cost in euro per m
        
q_j = {}
for j in J.index:
    if j.startswith('j'):
        q_j[j] = 255
    else:
        q_j[j] = 45



softlimit = 120
hardlimit = 10000

# %%
#Define distance matrices

def distance(point1, PointsSet1, point2, PointsSet2):
    c1 = np.array((PointsSet1.loc[point1, 'Longitude'], PointsSet1.loc[point1, 'Latitude']))
    c2 = np.array((PointsSet2.loc[point2, 'Longitude'], PointsSet2.loc[point2, 'Latitude']))
    return np.linalg.norm(c1-c2)

dist_JI = {(c1, c2): distance(c1, J, c2, I)for c1, c2 in itertools.product(J.index, I.index)}
dist_IK = {(c1, c2): distance(c1, I, c2, K)for c1, c2 in itertools.product(I.index, K.index)}
dist_KJ = {(c1, c2): distance(c1, K, c2, J)for c1, c2 in itertools.product(K.index, J.index)}


 
def softtime(model, where):
    if where == GRB.Callback.MIP:
        runtime = model.cbGet(GRB.Callback.RUNTIME)
        objbst = model.cbGet(GRB.Callback.MIP_OBJBST)
        objbnd = model.cbGet(GRB.Callback.MIP_OBJBND)
        gap = abs((objbst - objbnd) / objbst)

        if runtime > softlimit and gap < 0.5:
            model.terminate()
            

def SolutionSummary(model):
    n = -1
    results = pd.DataFrame(columns = ['i', 'k', 'j', 'Number of drones'])
    for opt_sol in range(1):
        for v in model.getVars():
            if v.varName.startswith('x_ikj'):
                if v.X > 0:
                    n += 1
                    indices = v.varName[6:-1].split(',') #drop variable name and brackets and convert to a list of indices
                    results.loc[n, 'i'] = indices[0]
                    results.loc[n, 'k'] = indices[1]
                    results.loc[n, 'j'] = indices[2]
                    results.loc[n, 'Number of drones'] = int(v.X)
    results_doctors = sum(results['Number of drones'])
    return results_doctors


total_drones = pd.DataFrame(columns = ['Prob model number of drones', 'Actual number of drones'])
o = 0

# %%
for i in range(0, 50):
    up_bound = 10
    mu = {i : int(round(random.uniform(1, up_bound), 0)) for i in I.index}

    theta_det = {}
    for n in I.index:
        theta_det[n] = list(poisson.rvs(mu[n], size = 1))[0]
    theta_det


    #Define set L
    L = list()
    for k, j in itertools.product(K.index, J.index):
        if dist_KJ[(k, j)] <= 0.5*B:
            L.append((k, j))
            


    #Define set P
    P = list()
    for i, k in itertools.product(I.index, K.index):
        if dist_IK[(i, k)] <= 0.5*B:
            P.append((i, k))


    #Define sets M_kj

    M_kj = {}
    M_interim = []

    for (k, j) in L:
        for i in I.index:
            if dist_JI[j, i] <= S:
                if dist_JI[j, i] + dist_IK[i, k] + dist_KJ[k, j] <= B:
                    M_interim.append(i)
        M_kj[(k, j)] = M_interim
        M_interim = []

    M_kj_final = {key : val for key, val in M_kj.items() if val != []}  

    KJ_feas = list(M_kj_final.keys())



    #Define sets N_i

    N_i = {}
    N_interim = []

    for i in I.index:
        for (k, j) in L:
            if dist_JI[j, i] <= S:
                if dist_JI[j, i] + dist_IK[i, k] + dist_KJ[k, j] <= B:
                    N_interim.append((k, j))
        N_i[i] = N_interim
        N_interim = []
        
    N_i_final = {key : val for key, val in N_i.items() if val != []}   
    
    I_feas = list(N_i_final.keys())



    #Define sets O_j

    O_j = {}
    O_interim = []

    for j in J.index:
        for (i, k) in P:
            if dist_JI[j, i] <= S:
                if dist_JI[j, i] + dist_IK[i, k] + dist_KJ[k, j] <= B:
                    O_interim.append((i, k))
        O_j[j] = O_interim
        O_interim = []
        
    O_j_final = {key : val for key, val in O_j.items() if val != []}   
    
    J_feas = list(O_j_final.keys())




    #Define constants and random variables

    theta_ran_i = {}
    for n in list(I.index):
        theta_ran_i[n] = poisson(mu[n])

    l_i = {}
    for i in theta_ran_i.keys():
        l_i[i] = int(theta_ran_i[i].ppf(p))


    g_i = {}
    for i in theta_ran_i.keys():
        g_i[i] = mu[i] * 7

    IG = []
    for i in I.index:
        for g in range(1, g_i[i] + 1):
            IG.append((i, g))

    I_feasG = []
    for i in I_feas:
        for g in range(1, g_i[i] + 1):
            I_feasG.append((i, g))
            

    h_ig = {}
    for (i, g) in I_feasG:
        h_ig[(i, g)] = math.log(theta_ran_i[i].cdf(l_i[i] + g)) - math.log(theta_ran_i[i].cdf(l_i[i] + g - 1))


    phi = float(math.log(p) - sum(theta_ran_i[i].cdf(l_i[i]) for i in I_feas))
    g_i



    model_prob = gp.Model('Probabilistic model without relaxation')

    x_ikj = model_prob.addVars(I.index, L, vtype = GRB.INTEGER, name = 'x_ikj')
    y_j = model_prob.addVars(J.index, vtype = GRB.BINARY, name = 'y_j')
    z_ig = model_prob.addVars(IG, vtype = GRB.BINARY, name = 'z_ig')

    #Probabilistic constraints

    model_prob.addConstr((gp.quicksum(h_ig[ig] * z_ig[ig] for ig in I_feasG)) >= phi, name = 'c15')
    model_prob.addConstrs((gp.quicksum(x_ikj[i, k, j] for (k, j) in N_i_final[i]) == l_i[i] + gp.quicksum(z_ig) for (i, g) in I_feasG), name = 'c16')


    #Same constraints as in the deterministic model

    model_prob.addConstrs((gp.quicksum(x_ikj[i, k, j] for (i, k) in O_j_final[j]) <= q_j[j] * y_j[j] for j in J_feas), name = 'c4')
    model_prob.addConstrs(((dist_JI[(j, i)] + dist_IK[(i, k)] + dist_KJ[(k, j)]) * x_ikj[i, k, j] <= B * x_ikj[i, k, j]
                    for i in I_feas for (k, j) in KJ_feas), name = 'c5')
    model_prob.addConstrs((dist_JI[(j, i)] * x_ikj[i, k, j] <= S * x_ikj[i, k, j] for i in I_feas for (k, j) in KJ_feas), name = 'c6')

    model_prob.setObjective(gp.quicksum(alpha * x_ikj[i, k, j] + gamma * (dist_JI[(j, i)] + dist_IK[(i, k)] + dist_KJ[(k, j)]) * x_ikj[i, k, j] for i in I_feas for (k, j) in KJ_feas) + gp.quicksum(beta[j] * y_j[j] for j in J_feas), GRB.MINIMIZE)

    model_prob.setParam('TimeLimit', hardlimit)
    model_prob.optimize(softtime)
    
    total_drones.loc[o, 'Prob model number of drones'] = SolutionSummary(model_prob)
    total_drones.loc[o, 'Actual number of drones'] = sum(theta_det.values())
    o += 1
# Out:
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Set parameter TimeLimit to value 10000
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1145G7 @ 2.60GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 165556 rows, 84859 columns and 12530243 nonzeros
# Model fingerprint: 0x5e0da98e
# Variable types: 0 continuous, 84859 integer (4163 binary)
# Coefficient statistics:
#   Matrix range     [1e-13, 9e+04]
#   Objective range  [2e+04, 2e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+00, 8e+01]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 3.183508e+07
# Presolve removed 161393 rows and 19499 columns (presolve time = 19s) ...
# Presolve removed 164431 rows and 19499 columns (presolve time = 20s) ...
# Presolve removed 164431 rows and 19499 columns
# Presolve time: 21.30s
# Presolved: 1125 rows, 65360 columns, 129747 nonzeros
# Variable types: 0 continuous, 65360 integer (1048 binary)
# Found heuristic solution: objective 3.183508e+07
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.1049980e+07   1.163750e+02   6.237200e+10     23s
#       85    2.2047933e+08   0.000000e+00   1.305975e+07     23s
#     8339    1.8449218e+07   0.000000e+00   0.000000e+00     23s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.844922e+07, 8339 iterations, 0.43 seconds (0.17 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.8449e+07    0   55 3.1835e+07 1.8449e+07  42.0%     -   22s
# H    0     0                    2.873455e+07 1.8449e+07  35.8%     -   22s
# H    0     0                    2.221716e+07 1.8449e+07  17.0%     -   24s
# H    0     0                    1.858455e+07 1.8449e+07  0.73%     -   29s
#      0     0 1.8449e+07    0   98 1.8585e+07 1.8449e+07  0.73%     -   29s
# H    0     0                    1.858455e+07 1.8449e+07  0.73%     -   31s
#      0     0 1.8449e+07    0  100 1.8585e+07 1.8449e+07  0.73%     -   32s
#      0     0 1.8449e+07    0  150 1.8585e+07 1.8449e+07  0.73%     -   32s
#      0     0 1.8449e+07    0  148 1.8585e+07 1.8449e+07  0.73%     -   33s
#      0     0 1.8449e+07    0  179 1.8585e+07 1.8449e+07  0.73%     -   33s
#      0     0 1.8449e+07    0  179 1.8585e+07 1.8449e+07  0.73%     -   33s
# H    0     0                    1.858455e+07 1.8449e+07  0.73%     -   37s
#      0     2 1.8449e+07    0  179 1.8585e+07 1.8449e+07  0.73%     -   37s
#     27    32 1.8449e+07    6  137 1.8585e+07 1.8449e+07  0.73%  51.2   43s
#     49    86 1.8449e+07   12  133 1.8585e+07 1.8449e+07  0.73%  45.4   45s
#    174   552 1.8449e+07   40  115 1.8585e+07 1.8449e+07  0.73%  35.8   54s
#    551   865 1.8449e+07  130  103 1.8585e+07 1.8449e+07  0.73%  29.0   59s
#    864  1293 1.8449e+07  194   61 1.8585e+07 1.8449e+07  0.73%  32.2   65s
# H 1164  1293                    1.858455e+07 1.8449e+07  0.73%  33.9   65s
#   1292  1754 1.8449e+07  280   57 1.8585e+07 1.8449e+07  0.73%  30.9   70s
#   1753  2311 1.8449e+07  392   57 1.8585e+07 1.8449e+07  0.73%  30.4   75s
#   2310  2835 1.8449e+07  525   40 1.8585e+07 1.8449e+07  0.73%  29.1   80s
# H 2533  2835                    1.853539e+07 1.8449e+07  0.46%  28.2   80s
#   2838  3185 1.8449e+07  742   18 1.8535e+07 1.8449e+07  0.46%  27.5   86s
# H 2959  3185                    1.853539e+07 1.8449e+07  0.46%  26.8   86s
# H 3194  4166                    1.853539e+07 1.8449e+07  0.46%  25.8   91s
# H 4216  4371                    1.853539e+07 1.8449e+07  0.46%  22.5   96s
#   4885  4828 1.8449e+07  708  179 1.8535e+07 1.8449e+07  0.46%  22.2  101s
#   4888  4830 1.8449e+07  812  102 1.8535e+07 1.8449e+07  0.46%  22.2  105s
#   4893  4833 1.8490e+07 1023  210 1.8535e+07 1.8449e+07  0.46%  22.1  110s
#   4896  4835 1.8449e+07  905  239 1.8535e+07 1.8449e+07  0.46%  22.1  117s
#   4924  4859 1.8449e+07   17  181 1.8535e+07 1.8449e+07  0.46%  26.0  122s
#
# Cutting planes:
#   Gomory: 2
#   Lift-and-project: 7
#   Implied bound: 388
#   MIR: 12
#   StrongCG: 5
#   Flow cover: 4
#   Zero half: 11
#   Relax-and-lift: 17
#
# Explored 4928 nodes (138362 simplex iterations) in 122.57 seconds (63.37 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 1.85354e+07 1.85354e+07 1.85354e+07 ... 2.87346e+07
#
# Solve interrupted
# Best objective 1.853539154350e+07, best bound 1.844921816169e+07, gap 0.4649%
#
# User-callback calls 14878, time in user-callback 0.14 sec
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Set parameter TimeLimit to value 10000
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1145G7 @ 2.60GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 165556 rows, 84859 columns and 12539387 nonzeros
# Model fingerprint: 0x9b632f73
# Variable types: 0 continuous, 84859 integer (4163 binary)
# Coefficient statistics:
#   Matrix range     [1e-13, 9e+04]
#   Objective range  [2e+04, 2e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+00, 8e+01]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 3.177148e+07
# Presolve removed 161393 rows and 19499 columns (presolve time = 18s) ...
# Presolve removed 164431 rows and 19499 columns (presolve time = 20s) ...
# Presolve removed 164431 rows and 19499 columns
# Presolve time: 20.41s
# Presolved: 1125 rows, 65360 columns, 129747 nonzeros
# Variable types: 0 continuous, 65360 integer (1048 binary)
# Found heuristic solution: objective 3.177148e+07
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.1009980e+07   1.157500e+02   6.049300e+10     22s
#       83    2.2041573e+08   0.000000e+00   1.305989e+07     22s
#     7859    1.8382433e+07   0.000000e+00   0.000000e+00     22s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.838243e+07, 7859 iterations, 0.36 seconds (0.17 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.8382e+07    0   53 3.1771e+07 1.8382e+07  42.1%     -   21s
# H    0     0                    2.826495e+07 1.8382e+07  35.0%     -   21s
# H    0     0                    2.276255e+07 1.8382e+07  19.2%     -   23s
# H    0     0                    1.852095e+07 1.8382e+07  0.75%     -   28s
#      0     0 1.8382e+07    0  101 1.8521e+07 1.8382e+07  0.75%     -   28s
# H    0     0                    1.852095e+07 1.8382e+07  0.75%     -   30s
#      0     0 1.8382e+07    0  103 1.8521e+07 1.8382e+07  0.75%     -   30s
#      0     0 1.8382e+07    0  152 1.8521e+07 1.8382e+07  0.75%     -   30s
#      0     0 1.8382e+07    0  153 1.8521e+07 1.8382e+07  0.75%     -   31s
#      0     0 1.8382e+07    0  195 1.8521e+07 1.8382e+07  0.75%     -   31s
#      0     0 1.8382e+07    0  195 1.8521e+07 1.8382e+07  0.75%     -   31s
#      0     2 1.8382e+07    0  195 1.8521e+07 1.8382e+07  0.75%     -   35s
#     47    83 1.8382e+07   11  158 1.8521e+07 1.8382e+07  0.75%  42.2   40s
#    176   422 1.8382e+07   43  128 1.8521e+07 1.8382e+07  0.75%  45.2   49s
#    421   839 1.8382e+07  105  128 1.8521e+07 1.8382e+07  0.75%  62.3   55s
#    838  1039 1.8382e+07  198  121 1.8521e+07 1.8382e+07  0.75%  64.1   64s
# H 1037  1039                    1.847179e+07 1.8382e+07  0.48%  63.3   64s
#   1038  1493 1.8382e+07  255  119 1.8472e+07 1.8382e+07  0.48%  63.3   71s
# H 1064  1493                    1.847179e+07 1.8382e+07  0.48%  62.8   71s
# H 1381  1493                    1.847179e+07 1.8382e+07  0.48%  60.4   71s
#   1492  2057 1.8382e+07  350  100 1.8472e+07 1.8382e+07  0.48%  60.8   77s
#   2056  2141 1.8382e+07  493   79 1.8472e+07 1.8382e+07  0.48%  54.2   92s
# H 2057  2141                    1.847179e+07 1.8382e+07  0.48%  54.2   92s
#   2140  2594 1.8382e+07  494   81 1.8472e+07 1.8382e+07  0.48%  52.5   98s
#   2593  3333 1.8382e+07  622   23 1.8472e+07 1.8382e+07  0.48%  44.8  104s
#   3332  4275 1.8382e+07  800    6 1.8472e+07 1.8382e+07  0.48%  37.5  110s
#   4293  4874 1.8456e+07 1025    2 1.8472e+07 1.8382e+07  0.48%  31.1  115s
#   4913  5412 1.8382e+07   90   72 1.8472e+07 1.8382e+07  0.48%  28.9  121s
#
# Cutting planes:
#   Implied bound: 249
#   MIR: 2
#   StrongCG: 1
#   Flow cover: 42
#   Zero half: 1
#   Network: 1
#   Relax-and-lift: 30
#
# Explored 5451 nodes (160336 simplex iterations) in 121.63 seconds (77.11 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 1.84718e+07 1.84718e+07 1.84718e+07 ... 3.17715e+07
#
# Solve interrupted
# Best objective 1.847179080761e+07, best bound 1.838243308501e+07, gap 0.4838%
#
# User-callback calls 15424, time in user-callback 0.15 sec
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Set parameter TimeLimit to value 10000
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1145G7 @ 2.60GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 165486 rows, 84789 columns and 12031672 nonzeros
# Model fingerprint: 0xaf0a3a0a
# Variable types: 0 continuous, 84789 integer (4093 binary)
# Coefficient statistics:
#   Matrix range     [1e-13, 9e+04]
#   Objective range  [2e+04, 2e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+00, 8e+01]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 3.153298e+07
# Presolve removed 161393 rows and 19429 columns (presolve time = 18s) ...
# Presolve removed 164361 rows and 19429 columns
# Presolve time: 19.89s
# Presolved: 1125 rows, 65360 columns, 129747 nonzeros
# Variable types: 0 continuous, 65360 integer (1048 binary)
# Found heuristic solution: objective 3.153298e+07
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0859980e+07   1.155000e+02   6.049300e+10     21s
#       82    2.2017723e+08   0.000000e+00   1.305989e+07     21s
#     7901    1.8131992e+07   0.000000e+00   0.000000e+00     21s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.813199e+07, 7901 iterations, 0.32 seconds (0.17 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.8132e+07    0   51 3.1533e+07 1.8132e+07  42.5%     -   21s
# H    0     0                    2.762045e+07 1.8132e+07  34.4%     -   21s
# H    0     0                    2.741745e+07 1.8132e+07  33.9%     -   21s
# H    0     0                    2.090005e+07 1.8132e+07  13.2%     -   21s
# H    0     0                    1.828245e+07 1.8132e+07  0.82%     -   26s
#      0     0 1.8132e+07    0  115 1.8282e+07 1.8132e+07  0.82%     -   27s
# H    0     0                    1.828245e+07 1.8132e+07  0.82%     -   29s
#      0     0 1.8132e+07    0  119 1.8282e+07 1.8132e+07  0.82%     -   29s
#      0     0 1.8132e+07    0  160 1.8282e+07 1.8132e+07  0.82%     -   29s
#      0     0 1.8132e+07    0  160 1.8282e+07 1.8132e+07  0.82%     -   30s
#      0     0 1.8132e+07    0  187 1.8282e+07 1.8132e+07  0.82%     -   30s
#      0     0 1.8132e+07    0  187 1.8282e+07 1.8132e+07  0.82%     -   31s
#      0     2 1.8132e+07    0  187 1.8282e+07 1.8132e+07  0.82%     -   34s
#      7    12 1.8132e+07    3  185 1.8282e+07 1.8132e+07  0.82%  41.4   35s
# H   30    32                    1.823329e+07 1.8132e+07  0.56%  46.8   37s
#     52    82 1.8132e+07   15  149 1.8233e+07 1.8132e+07  0.56%  34.3   40s
# H   81   126                    1.823329e+07 1.8132e+07  0.56%  31.5   44s
# H  107   126                    1.823329e+07 1.8132e+07  0.56%  32.9   44s
#    125   367 1.8132e+07   37  109 1.8233e+07 1.8132e+07  0.56%  34.9   50s
#    366   709 1.8132e+07  103   82 1.8233e+07 1.8132e+07  0.56%  37.5   56s
#    708  1099 1.8132e+07  187   63 1.8233e+07 1.8132e+07  0.56%  44.3   65s
#   1098  1783 1.8132e+07  262   60 1.8233e+07 1.8132e+07  0.56%  44.1   71s
#   1782  2270 1.8132e+07  374   58 1.8233e+07 1.8132e+07  0.56%  41.9   77s
#   2269  2885 1.8132e+07  498   41 1.8233e+07 1.8132e+07  0.56%  39.6   81s
#   2884  3246 1.8132e+07  687    7 1.8233e+07 1.8132e+07  0.56%  35.0   91s
#   3248  4182 1.8132e+07  805    5 1.8233e+07 1.8132e+07  0.56%  32.5   96s
#   4281  4422 1.8173e+07 1041    1 1.8233e+07 1.8132e+07  0.56%  27.3  100s
#   4729  4607 1.8173e+07  835  187 1.8233e+07 1.8132e+07  0.56%  28.6  105s
#   4733  4610 1.8132e+07  922  139 1.8233e+07 1.8132e+07  0.56%  28.6  110s
#   4737  4612 1.8132e+07  514  233 1.8233e+07 1.8132e+07  0.56%  28.6  115s
#   4740  4614 1.8132e+07   32  246 1.8233e+07 1.8132e+07  0.56%  28.6  121s
#
# Cutting planes:
#   Gomory: 3
#   Lift-and-project: 5
#   Implied bound: 336
#   MIR: 18
#   StrongCG: 3
#   Flow cover: 21
#   Zero half: 8
#   Network: 1
#   Relax-and-lift: 12
#
# Explored 4740 nodes (156841 simplex iterations) in 121.68 seconds (66.47 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 1.82333e+07 1.82333e+07 1.82333e+07 ... 3.1533e+07
#
# Solve interrupted
# Best objective 1.823329094593e+07, best bound 1.813199206756e+07, gap 0.5556%
#
# User-callback calls 13101, time in user-callback 0.06 sec
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Set parameter TimeLimit to value 10000
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1145G7 @ 2.60GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 165402 rows, 84705 columns and 11484882 nonzeros
# Model fingerprint: 0x5ea48756
# Variable types: 0 continuous, 84705 integer (4009 binary)
# Coefficient statistics:
#   Matrix range     [1e-13, 9e+04]
#   Objective range  [2e+04, 2e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+00, 8e+01]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 3.115138e+07
# Presolve removed 161393 rows and 19345 columns (presolve time = 16s) ...
# Presolve removed 164277 rows and 19345 columns
# Presolve time: 17.84s
# Presolved: 1125 rows, 65360 columns, 129747 nonzeros
# Variable types: 0 continuous, 65360 integer (1048 binary)
# Found heuristic solution: objective 3.115138e+07
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0619980e+07   1.110000e+02   6.049300e+10     19s
#       82    2.1979562e+08   0.000000e+00   1.305989e+07     19s
#     8063    1.7731283e+07   0.000000e+00   0.000000e+00     19s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.773128e+07, 8063 iterations, 0.39 seconds (0.18 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.7731e+07    0   51 3.1151e+07 1.7731e+07  43.1%     -   19s
# H    0     0                    2.723885e+07 1.7731e+07  34.9%     -   19s
# H    0     0                    2.703585e+07 1.7731e+07  34.4%     -   19s
# H    0     0                    2.206553e+07 1.7731e+07  19.6%     -   20s
# H    0     0                    1.790085e+07 1.7731e+07  0.95%     -   25s
#      0     0 1.7731e+07    0   95 1.7901e+07 1.7731e+07  0.95%     -   26s
#      0     0 1.7731e+07    0  168 1.7901e+07 1.7731e+07  0.95%     -   28s
#      0     0 1.7731e+07    0  179 1.7901e+07 1.7731e+07  0.95%     -   28s
#      0     0 1.7731e+07    0  184 1.7901e+07 1.7731e+07  0.95%     -   28s
#      0     0 1.7731e+07    0  184 1.7901e+07 1.7731e+07  0.95%     -   29s
# H    0     0                    1.790085e+07 1.7731e+07  0.95%     -   31s
#      0     2 1.7731e+07    0  184 1.7901e+07 1.7731e+07  0.95%     -   32s
#     27    32 1.7731e+07    8  191 1.7901e+07 1.7731e+07  0.95%  63.1   38s
# H   30    32                    1.777477e+07 1.7731e+07  0.24%  58.2   38s
#     47   106 1.7731e+07   14  175 1.7775e+07 1.7731e+07  0.24%  43.9   40s
# H  244   535                    1.777477e+07 1.7731e+07  0.24%  35.1   49s
#    534   814 1.7731e+07  132   56 1.7775e+07 1.7731e+07  0.24%  34.8   55s
#    813  1269 1.7731e+07  205   51 1.7775e+07 1.7731e+07  0.24%  31.2   62s
#   1268  1678 1.7731e+07  313   47 1.7775e+07 1.7731e+07  0.24%  29.4   68s
#   1677  2367 1.7731e+07  402   41 1.7775e+07 1.7731e+07  0.24%  30.1   73s
#   2366  2676 1.7731e+07  538   41 1.7775e+07 1.7731e+07  0.24%  31.3   83s
#   2675  3183 1.7731e+07  627   24 1.7775e+07 1.7731e+07  0.24%  29.0   88s
#   3182  3835 1.7731e+07  754    5 1.7775e+07 1.7731e+07  0.24%  26.3   93s
#   3840  4405 1.7731e+07  914    2 1.7775e+07 1.7731e+07  0.24%  22.8   99s
#   4439  5161 1.7731e+07    8  101 1.7775e+07 1.7731e+07  0.24%  20.9  104s
#   5201  5162 1.7773e+07  871  184 1.7775e+07 1.7731e+07  0.24%  19.6  106s
#   5204  5164 1.7731e+07  177   84 1.7775e+07 1.7731e+07  0.24%  19.6  113s
#   5208  5167 1.7731e+07  832  235 1.7775e+07 1.7731e+07  0.24%  19.6  115s
#   5212  5169 1.7731e+07  446  237 1.7775e+07 1.7731e+07  0.24%  19.5  121s
#
# Cutting planes:
#   Gomory: 2
#   Lift-and-project: 7
#   Implied bound: 329
#   MIR: 38
#   Flow cover: 5
#   Zero half: 6
#   Relax-and-lift: 16
#
# Explored 5212 nodes (128842 simplex iterations) in 121.37 seconds (64.88 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 9: 1.77748e+07 1.77748e+07 1.79008e+07 ... 3.11514e+07
#
# Solve interrupted
# Best objective 1.777476797352e+07, best bound 1.773128318014e+07, gap 0.2446%
#
# User-callback calls 14658, time in user-callback 0.16 sec
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Set parameter TimeLimit to value 10000
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1145G7 @ 2.60GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 165213 rows, 84516 columns and 10252789 nonzeros
# Model fingerprint: 0x0cb19b4e
# Variable types: 0 continuous, 84516 integer (3820 binary)
# Coefficient statistics:
#   Matrix range     [1e-13, 9e+04]
#   Objective range  [2e+04, 2e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+00, 8e+01]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 3.038818e+07
# Presolve removed 161393 rows and 19156 columns (presolve time = 12s) ...
# Presolve removed 164088 rows and 19156 columns
# Presolve time: 12.77s
# Presolved: 1125 rows, 65360 columns, 129747 nonzeros
# Variable types: 0 continuous, 65360 integer (1048 binary)
# Found heuristic solution: objective 3.038818e+07
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0139981e+07   1.065000e+02   6.049300e+10     14s
#       84    2.1903242e+08   0.000000e+00   1.305994e+07     14s
#     8071    1.6929870e+07   0.000000e+00   0.000000e+00     14s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.692987e+07, 8071 iterations, 0.17 seconds (0.17 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.6930e+07    0   52 3.0388e+07 1.6930e+07  44.3%     -   13s
# H    0     0                    2.667865e+07 1.6930e+07  36.5%     -   13s
# H    0     0                    2.606965e+07 1.6930e+07  35.1%     -   13s
# H    0     0                    2.117625e+07 1.6930e+07  20.1%     -   14s
# H    0     0                    1.693465e+07 1.6930e+07  0.03%     -   16s
#      0     0 1.6930e+07    0   87 1.6935e+07 1.6930e+07  0.03%     -   16s
# H    0     0                    1.693465e+07 1.6930e+07  0.03%     -   17s
#      0     0 1.6930e+07    0   95 1.6935e+07 1.6930e+07  0.03%     -   17s
#      0     0 1.6930e+07    0  154 1.6935e+07 1.6930e+07  0.03%     -   17s
#      0     0 1.6930e+07    0  170 1.6935e+07 1.6930e+07  0.03%     -   17s
#      0     0 1.6930e+07    0  183 1.6935e+07 1.6930e+07  0.03%     -   17s
#      0     0 1.6930e+07    0  183 1.6935e+07 1.6930e+07  0.03%     -   18s
#      0     2 1.6930e+07    0  183 1.6935e+07 1.6930e+07  0.03%     -   19s
#     19    24 1.6930e+07    5  198 1.6935e+07 1.6930e+07  0.03%  43.7   20s
#    184   545 1.6930e+07   33  116 1.6935e+07 1.6930e+07  0.03%  33.3   25s
#    662  1131 1.6930e+07  191   35 1.6935e+07 1.6930e+07  0.03%  31.3   30s
#   2031  2403 1.6930e+07  571   17 1.6935e+07 1.6930e+07  0.03%  28.0   39s
#   2410  3619 1.6930e+07  727   14 1.6935e+07 1.6930e+07  0.03%  25.0   42s
#   4203  4488 1.6930e+07   84   36 1.6935e+07 1.6930e+07  0.03%  20.6   46s
#   4603  4492 1.6930e+07   52  175 1.6935e+07 1.6930e+07  0.03%  20.1   50s
#   4609  4496 1.6930e+07  828  224 1.6935e+07 1.6930e+07  0.03%  20.1   55s
#   4640  4518 1.6930e+07   19  166 1.6935e+07 1.6930e+07  0.03%  22.8   60s
#   4807  4866 1.6930e+07   42  170 1.6935e+07 1.6930e+07  0.03%  26.1   69s
#   5072  5152 1.6930e+07   82  157 1.6935e+07 1.6930e+07  0.03%  26.8   74s
#   5462  5299 1.6930e+07  145  160 1.6935e+07 1.6930e+07  0.03%  30.4   80s
#   5769  5473 1.6930e+07  226  157 1.6935e+07 1.6930e+07  0.03%  35.6   88s
#   6101  5546 1.6930e+07  268  186 1.6935e+07 1.6930e+07  0.03%  39.1   95s
#   6348  5755     cutoff  285      1.6935e+07 1.6930e+07  0.03%  41.9  102s
#   6675  5768 1.6930e+07  315  117 1.6935e+07 1.6930e+07  0.03%  44.6  109s
#   6928  5802 1.6930e+07  353  132 1.6935e+07 1.6930e+07  0.03%  48.5  116s
#   7173  5871 1.6930e+07  378  118 1.6935e+07 1.6930e+07  0.03%  52.4  125s
#
# Cutting planes:
#   Gomory: 3
#   Lift-and-project: 4
#   Implied bound: 410
#   MIR: 30
#   StrongCG: 6
#   Flow cover: 25
#   Zero half: 7
#   Network: 1
#   Relax-and-lift: 19
#
# Explored 7453 nodes (428190 simplex iterations) in 125.33 seconds (143.34 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: 1.69346e+07 1.69346e+07 2.11762e+07 ... 3.03882e+07
#
# Solve interrupted
# Best objective 1.693464609902e+07, best bound 1.692986956077e+07, gap 0.0282%
#
# User-callback calls 19542, time in user-callback 0.14 sec
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Set parameter TimeLimit to value 10000
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1145G7 @ 2.60GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 165381 rows, 84684 columns and 11326622 nonzeros
# Model fingerprint: 0x4d164de6
# Variable types: 0 continuous, 84684 integer (3988 binary)
# Coefficient statistics:
#   Matrix range     [1e-13, 9e+04]
#   Objective range  [2e+04, 2e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+00, 8e+01]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 3.100828e+07
# Presolve removed 161393 rows and 19324 columns (presolve time = 16s) ...
# Presolve removed 164256 rows and 19324 columns
# Presolve time: 17.43s
# Presolved: 1125 rows, 65360 columns, 129747 nonzeros
# Variable types: 0 continuous, 65360 integer (1048 binary)
# Found heuristic solution: objective 3.100828e+07
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0529981e+07   1.098750e+02   6.049300e+10     19s
#       81    2.1965252e+08   0.000000e+00   1.305989e+07     19s
#     7950    1.7581019e+07   0.000000e+00   0.000000e+00     19s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.758102e+07, 7950 iterations, 0.47 seconds (0.17 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.7581e+07    0   50 3.1008e+07 1.7581e+07  43.3%     -   18s
# H    0     0                    2.689275e+07 1.7581e+07  34.6%     -   19s
# H    0     0                    2.668975e+07 1.7581e+07  34.1%     -   19s
# H    0     0                    2.128567e+07 1.7581e+07  17.4%     -   19s
# H    0     0                    1.775775e+07 1.7581e+07  1.00%     -   24s
#      0     0 1.7581e+07    0   93 1.7758e+07 1.7581e+07  1.00%     -   25s
#      0     0 1.7581e+07    0   99 1.7758e+07 1.7581e+07  1.00%     -   28s
#      0     0 1.7581e+07    0  160 1.7758e+07 1.7581e+07  1.00%     -   29s
#      0     0 1.7581e+07    0  161 1.7758e+07 1.7581e+07  1.00%     -   29s
#      0     0 1.7581e+07    0  188 1.7758e+07 1.7581e+07  1.00%     -   29s
#      0     0 1.7581e+07    0  188 1.7758e+07 1.7581e+07  1.00%     -   30s
#      0     2 1.7581e+07    0  188 1.7758e+07 1.7581e+07  1.00%     -   33s
#     27    32 1.7581e+07    6  201 1.7758e+07 1.7581e+07  1.00%  45.4   35s
#     82   179 1.7581e+07   18  141 1.7758e+07 1.7581e+07  1.00%  23.6   40s
# H  153   179                    1.763167e+07 1.7581e+07  0.29%  26.9   40s
# H  178   419                    1.763167e+07 1.7581e+07  0.29%  34.7   45s
#    418   811 1.7581e+07   96  109 1.7632e+07 1.7581e+07  0.29%  66.4   52s
#    810  1078 1.7581e+07  188   99 1.7632e+07 1.7581e+07  0.29%  63.1   58s
#   1077  1477 1.7581e+07  252   99 1.7632e+07 1.7581e+07  0.29%  64.6   64s
#   1476  1971 1.7581e+07  347   99 1.7632e+07 1.7581e+07  0.29%  63.6   70s
#   1970  2269 1.7581e+07  472   53 1.7632e+07 1.7581e+07  0.29%  56.4   78s
# H 2173  2269                    1.763167e+07 1.7581e+07  0.29%  52.0   78s
#   2268  2791 1.7581e+07  570   23 1.7632e+07 1.7581e+07  0.29%  50.2   84s
#   2790  3097 1.7581e+07  679   19 1.7632e+07 1.7581e+07  0.29%  42.9   93s
# H 3094  3097                    1.763167e+07 1.7581e+07  0.29%  40.1   93s
#   3096  3698 1.7581e+07  822    3 1.7632e+07 1.7581e+07  0.29%  40.1  100s
#   3697  4609 1.7581e+07  906    3 1.7632e+07 1.7581e+07  0.29%  35.4  106s
#   4646  5441 1.7581e+07   59   46 1.7632e+07 1.7581e+07  0.29%  30.6  111s
#   5482  5444 1.7581e+07  593   82 1.7632e+07 1.7581e+07  0.29%  29.0  118s
#   5485  5446 1.7581e+07  268  164 1.7632e+07 1.7581e+07  0.29%  29.0  120s
#
# Cutting planes:
#   Gomory: 2
#   Lift-and-project: 1
#   Implied bound: 241
#   MIR: 25
#   StrongCG: 7
#   Flow cover: 37
#   Zero half: 8
#   Relax-and-lift: 20
#
# Explored 5485 nodes (180611 simplex iterations) in 121.33 seconds (66.28 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 1.76317e+07 1.76317e+07 1.76317e+07 ... 3.10083e+07
#
# Solve interrupted
# Best objective 1.763166801753e+07, best bound 1.758101852087e+07, gap 0.2873%
#
# User-callback calls 15927, time in user-callback 0.17 sec
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Set parameter TimeLimit to value 10000
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1145G7 @ 2.60GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 165353 rows, 84656 columns and 11147964 nonzeros
# Model fingerprint: 0x80224a76
# Variable types: 0 continuous, 84656 integer (3960 binary)
# Coefficient statistics:
#   Matrix range     [1e-13, 9e+04]
#   Objective range  [2e+04, 2e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+00, 8e+01]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 3.092878e+07
# Presolve removed 161393 rows and 19296 columns (presolve time = 16s) ...
# Presolve removed 164228 rows and 19296 columns
# Presolve time: 18.05s
# Presolved: 1125 rows, 65360 columns, 129747 nonzeros
# Variable types: 0 continuous, 65360 integer (1048 binary)
# Found heuristic solution: objective 3.092878e+07
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0479981e+07   1.116250e+02   6.049300e+10     19s
#       81    2.1957302e+08   0.000000e+00   1.305989e+07     19s
#     8036    1.7497539e+07   0.000000e+00   0.000000e+00     19s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.749754e+07, 8036 iterations, 0.45 seconds (0.17 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.7498e+07    0   53 3.0929e+07 1.7498e+07  43.4%     -   19s
# H    0     0                    2.742225e+07 1.7498e+07  36.2%     -   19s
# H    0     0                    2.721925e+07 1.7498e+07  35.7%     -   19s
# H    0     0                    2.191985e+07 1.7498e+07  20.2%     -   19s
# H    0     0                    1.767825e+07 1.7498e+07  1.02%     -   24s
# H    0     0                    1.767825e+07 1.7498e+07  1.02%     -   24s
#      0     0 1.7498e+07    0  105 1.7678e+07 1.7498e+07  1.02%     -   24s
#      0     0 1.7498e+07    0  111 1.7678e+07 1.7498e+07  1.02%     -   27s
#      0     0 1.7498e+07    0  148 1.7678e+07 1.7498e+07  1.02%     -   27s
#      0     0 1.7498e+07    0  143 1.7678e+07 1.7498e+07  1.02%     -   27s
#      0     0 1.7498e+07    0  178 1.7678e+07 1.7498e+07  1.02%     -   28s
#      0     0 1.7498e+07    0  178 1.7678e+07 1.7498e+07  1.02%     -   28s
#      0     2 1.7498e+07    0  178 1.7678e+07 1.7498e+07  1.02%     -   32s
# H   27    32                    1.767825e+07 1.7498e+07  1.02%  35.2   35s
# H   30    32                    1.762909e+07 1.7498e+07  0.75%  32.7   35s
# H   67    93                    1.762909e+07 1.7498e+07  0.75%  24.3   38s
#     92   175 1.7498e+07   20  171 1.7629e+07 1.7498e+07  0.75%  22.8   41s
# H   97   175                    1.762909e+07 1.7498e+07  0.75%  22.6   41s
#    174   437 1.7498e+07   38  123 1.7629e+07 1.7498e+07  0.75%  26.5   48s
# H  224   437                    1.755217e+07 1.7498e+07  0.31%  26.3   48s
# H  426   437                    1.755217e+07 1.7498e+07  0.31%  40.0   48s
#    436   711 1.7498e+07  101   88 1.7552e+07 1.7498e+07  0.31%  41.3   56s
#    710  1094 1.7498e+07  188   71 1.7552e+07 1.7498e+07  0.31%  49.4   63s
#   1093  1561 1.7498e+07  301   69 1.7552e+07 1.7498e+07  0.31%  52.3   69s
#   1560  2354 1.7498e+07  400   66 1.7552e+07 1.7498e+07  0.31%  51.8   76s
#   2353  2853 1.7498e+07  591   39 1.7552e+07 1.7498e+07  0.31%  44.4   81s
#   2852  3518 1.7498e+07  711   19 1.7552e+07 1.7498e+07  0.31%  39.0   86s
#   3517  3935 1.7498e+07  864   11 1.7552e+07 1.7498e+07  0.31%  35.3   95s
#   3944  4762 1.7523e+07 1023    1 1.7552e+07 1.7498e+07  0.31%  32.3  100s
#   4806  5381 1.7498e+07   63   59 1.7552e+07 1.7498e+07  0.31%  29.4  106s
#   5429  5384 1.7498e+07   16   80 1.7552e+07 1.7498e+07  0.31%  27.6  113s
#   5430  5385 1.7498e+07  392  141 1.7552e+07 1.7498e+07  0.31%  27.6  115s
#
# Cutting planes:
#   Gomory: 4
#   Lift-and-project: 3
#   Implied bound: 326
#   MIR: 37
#   StrongCG: 4
#   Flow cover: 66
#   Zero half: 5
#   Network: 1
#   Relax-and-lift: 42
#
# Explored 5434 nodes (173197 simplex iterations) in 122.24 seconds (63.94 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 1.75522e+07 1.75522e+07 1.76291e+07 ... 2.72192e+07
#
# Solve interrupted
# Best objective 1.755216906706e+07, best bound 1.749753921070e+07, gap 0.3112%
#
# User-callback calls 16185, time in user-callback 0.13 sec
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Set parameter TimeLimit to value 10000
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1145G7 @ 2.60GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 165563 rows, 84866 columns and 12558598 nonzeros
# Model fingerprint: 0xf275acd3
# Variable types: 0 continuous, 84866 integer (4170 binary)
# Coefficient statistics:
#   Matrix range     [1e-13, 9e+04]
#   Objective range  [2e+04, 2e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+00, 8e+01]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 3.173968e+07
# Presolve removed 161393 rows and 19506 columns (presolve time = 20s) ...
# Presolve removed 161393 rows and 19506 columns (presolve time = 20s) ...
# Presolve removed 164438 rows and 19506 columns
# Presolve time: 21.83s
# Presolved: 1125 rows, 65360 columns, 129747 nonzeros
# Variable types: 0 continuous, 65360 integer (1048 binary)
# Found heuristic solution: objective 3.173968e+07
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0989980e+07   1.147500e+02   6.237200e+10     23s
#       83    2.2038393e+08   0.000000e+00   1.305975e+07     23s
#     8510    1.8349041e+07   0.000000e+00   0.000000e+00     23s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.834904e+07, 8510 iterations, 0.38 seconds (0.17 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.8349e+07    0   48 3.1740e+07 1.8349e+07  42.2%     -   23s
# H    0     0                    2.721815e+07 1.8349e+07  32.6%     -   23s
# H    0     0                    2.701515e+07 1.8349e+07  32.1%     -   23s
# H    0     0                    2.245083e+07 1.8349e+07  18.3%     -   23s
# H    0     0                    1.848915e+07 1.8349e+07  0.76%     -   28s
#      0     0 1.8349e+07    0   96 1.8489e+07 1.8349e+07  0.76%     -   29s
# H    0     0                    1.848915e+07 1.8349e+07  0.76%     -   31s
#      0     0 1.8349e+07    0  102 1.8489e+07 1.8349e+07  0.76%     -   31s
#      0     0 1.8349e+07    0  149 1.8489e+07 1.8349e+07  0.76%     -   31s
#      0     0 1.8349e+07    0  160 1.8489e+07 1.8349e+07  0.76%     -   32s
#      0     0 1.8349e+07    0  192 1.8489e+07 1.8349e+07  0.76%     -   32s
#      0     0 1.8349e+07    0  192 1.8489e+07 1.8349e+07  0.76%     -   32s
#      0     2 1.8349e+07    0  192 1.8489e+07 1.8349e+07  0.76%     -   35s
#     27    32 1.8349e+07    6  153 1.8489e+07 1.8349e+07  0.76%  40.7   40s
# H   29    32                    1.848915e+07 1.8349e+07  0.76%  38.7   40s
#     99   201 1.8349e+07   36  125 1.8489e+07 1.8349e+07  0.76%  25.2   47s
#    200   615 1.8349e+07   62  107 1.8489e+07 1.8349e+07  0.76%  29.0   53s
#    614  1001 1.8349e+07  139  102 1.8489e+07 1.8349e+07  0.76%  39.7   59s
#   1000  1351 1.8349e+07  208  106 1.8489e+07 1.8349e+07  0.76%  42.3   65s
# H 1219  1351                    1.848915e+07 1.8349e+07  0.76%  41.4   65s
#   1350  1846 1.8349e+07  290  101 1.8489e+07 1.8349e+07  0.76%  41.8   70s
#   1845  2316 1.8349e+07  379   94 1.8489e+07 1.8349e+07  0.76%  41.4   76s
# H 2089  2316                    1.848915e+07 1.8349e+07  0.76%  39.7   76s
# H 2223  2316                    1.844000e+07 1.8349e+07  0.49%  39.2   76s
# H 2315  2807                    1.844000e+07 1.8349e+07  0.49%  38.8   85s
# H 2315  2807                    1.844000e+07 1.8349e+07  0.49%  38.8   85s
# H 2499  2807                    1.844000e+07 1.8349e+07  0.49%  37.1   85s
# H 2806  3244                    1.844000e+07 1.8349e+07  0.49%  34.5   90s
# H 3043  3244                    1.844000e+07 1.8349e+07  0.49%  33.3   90s
#   3243  4074 1.8349e+07  760    4 1.8440e+07 1.8349e+07  0.49%  31.7   95s
#   4112  4888 1.8349e+07   82   51 1.8440e+07 1.8349e+07  0.49%  27.3  100s
# H 4683  4888                    1.844000e+07 1.8349e+07  0.49%  24.9  100s
# H 4941  5375                    1.844000e+07 1.8349e+07  0.49%  23.9  106s
# H 5431  5108                    1.843999e+07 1.8349e+07  0.49%  22.3  112s
#   5435  5111 1.8349e+07  583  186 1.8440e+07 1.8349e+07  0.49%  22.3  115s
#   5440  5114 1.8349e+07  106  188 1.8440e+07 1.8349e+07  0.49%  22.3  124s
#
# Cutting planes:
#   Gomory: 2
#   Lift-and-project: 3
#   Implied bound: 311
#   MIR: 20
#   StrongCG: 5
#   Flow cover: 47
#   Zero half: 5
#   Relax-and-lift: 30
#
# Explored 5440 nodes (145011 simplex iterations) in 124.24 seconds (63.84 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 1.844e+07 1.844e+07 1.844e+07 ... 1.84892e+07
#
# Solve interrupted
# Best objective 1.843999128399e+07, best bound 1.834904133001e+07, gap 0.4932%
#
# User-callback calls 15093, time in user-callback 0.15 sec
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Set parameter TimeLimit to value 10000
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1145G7 @ 2.60GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 165255 rows, 84558 columns and 10507751 nonzeros
# Model fingerprint: 0x653ae356
# Variable types: 0 continuous, 84558 integer (3862 binary)
# Coefficient statistics:
#   Matrix range     [1e-13, 9e+04]
#   Objective range  [2e+04, 2e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+00, 8e+01]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 3.046768e+07
# Presolve removed 161393 rows and 19198 columns (presolve time = 15s) ...
# Presolve removed 164130 rows and 19198 columns (presolve time = 16s) ...
# Presolve removed 164130 rows and 19198 columns
# Presolve time: 16.41s
# Presolved: 1125 rows, 65360 columns, 129747 nonzeros
# Variable types: 0 continuous, 65360 integer (1048 binary)
# Found heuristic solution: objective 3.046768e+07
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0189981e+07   1.061250e+02   6.049300e+10     18s
#       82    2.1911192e+08   0.000000e+00   1.305989e+07     18s
#     7920    1.7013351e+07   0.000000e+00   0.000000e+00     18s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.701335e+07, 7920 iterations, 0.37 seconds (0.17 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.7013e+07    0   52 3.0468e+07 1.7013e+07  44.2%     -   17s
# H    0     0                    2.675815e+07 1.7013e+07  36.4%     -   17s
# H    0     0                    2.173867e+07 1.7013e+07  21.7%     -   19s
# H    0     0                    1.701415e+07 1.7013e+07  0.00%     -   21s
#
# Explored 1 nodes (7921 simplex iterations) in 22.05 seconds (4.06 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 1.70141e+07 2.17387e+07 2.67581e+07 ... 3.04677e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.701414671326e+07, best bound 1.701335050001e+07, gap 0.0047%
#
# User-callback calls 741, time in user-callback 0.00 sec
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Set parameter TimeLimit to value 10000
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1145G7 @ 2.60GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 165423 rows, 84726 columns and 11613691 nonzeros
# Model fingerprint: 0x9b17f8de
# Variable types: 0 continuous, 84726 integer (4030 binary)
# Coefficient statistics:
#   Matrix range     [1e-13, 9e+04]
#   Objective range  [2e+04, 2e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+00, 8e+01]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 3.126268e+07
# Presolve removed 161393 rows and 19366 columns (presolve time = 17s) ...
# Presolve removed 164298 rows and 19366 columns
# Presolve time: 19.17s
# Presolved: 1125 rows, 65360 columns, 129747 nonzeros
# Variable types: 0 continuous, 65360 integer (1048 binary)
# Found heuristic solution: objective 3.126268e+07
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0689980e+07   1.112500e+02   6.237200e+10     20s
#       83    2.1990692e+08   0.000000e+00   1.305975e+07     20s
#     8260    1.7848156e+07   0.000000e+00   0.000000e+00     21s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.784816e+07, 8260 iterations, 0.41 seconds (0.17 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.7848e+07    0   51 3.1263e+07 1.7848e+07  42.9%     -   20s
# H    0     0                    2.735015e+07 1.7848e+07  34.7%     -   20s
# H    0     0                    2.281359e+07 1.7848e+07  21.8%     -   22s
# H    0     0                    1.801215e+07 1.7848e+07  0.91%     -   26s
# H    0     0                    1.801215e+07 1.7848e+07  0.91%     -   27s
#      0     0 1.7848e+07    0   99 1.8012e+07 1.7848e+07  0.91%     -   27s
#      0     0 1.7848e+07    0  108 1.8012e+07 1.7848e+07  0.91%     -   29s
#      0     0 1.7848e+07    0  149 1.8012e+07 1.7848e+07  0.91%     -   29s
#      0     0 1.7848e+07    0  166 1.8012e+07 1.7848e+07  0.91%     -   30s
#      0     0 1.7848e+07    0  186 1.8012e+07 1.7848e+07  0.91%     -   30s
#      0     0 1.7848e+07    0  186 1.8012e+07 1.7848e+07  0.91%     -   31s
#      0     2 1.7848e+07    0  186 1.8012e+07 1.7848e+07  0.91%     -   34s
#      3     8 1.7848e+07    2  181 1.8012e+07 1.7848e+07  0.91%  19.0   35s
# H   28    32                    1.796299e+07 1.7848e+07  0.64%  56.7   37s
#     51    79 1.7848e+07   12  183 1.7963e+07 1.7848e+07  0.64%  39.3   43s
# H   57    79                    1.796299e+07 1.7848e+07  0.64%  36.1   43s
# H   70    79                    1.796299e+07 1.7848e+07  0.64%  32.1   43s
#     78   225 1.7848e+07   19  159 1.7963e+07 1.7848e+07  0.64%  31.2   48s
#    224   890 1.7848e+07   48  100 1.7963e+07 1.7848e+07  0.64%  23.0   56s
#    889  1284 1.7848e+07  163   98 1.7963e+07 1.7848e+07  0.64%  24.0   60s
#   1283  1602 1.7848e+07  233   94 1.7963e+07 1.7848e+07  0.64%  22.6   65s
#   1997  2672 1.7848e+07  408   91 1.7963e+07 1.7848e+07  0.64%  23.2   74s
#   2671  3274 1.7848e+07  618   41 1.7963e+07 1.7848e+07  0.64%  20.6   86s
#   3273  4045 1.7848e+07  884   11 1.7963e+07 1.7848e+07  0.64%  19.4   91s
#   4077  4412 1.7848e+07    9  132 1.7963e+07 1.7848e+07  0.64%  17.6   96s
#   4448  4943 1.7848e+07   54   34 1.7963e+07 1.7848e+07  0.64%  17.8  100s
#   5419  5375 1.7848e+07  383  186 1.7963e+07 1.7848e+07  0.64%  19.2  105s
#   5422  5377 1.7848e+07  333   76 1.7963e+07 1.7848e+07  0.64%  19.2  112s
#   5425  5379 1.7848e+07  474  202 1.7963e+07 1.7848e+07  0.64%  19.2  115s
#   5430  5382 1.7848e+07  734  266 1.7963e+07 1.7848e+07  0.64%  19.2  123s
#
# Cutting planes:
#   Gomory: 3
#   Lift-and-project: 2
#   Implied bound: 338
#   MIR: 17
#   Flow cover: 21
#   Zero half: 7
#   Network: 1
#   Relax-and-lift: 21
#
# Explored 5430 nodes (126681 simplex iterations) in 123.81 seconds (60.86 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 9: 1.7963e+07 1.7963e+07 1.7963e+07 ... 3.12627e+07
#
# Solve interrupted
# Best objective 1.796298836407e+07, best bound 1.784815616683e+07, gap 0.6393%
#
# User-callback calls 15974, time in user-callback 0.18 sec
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Set parameter TimeLimit to value 10000
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1145G7 @ 2.60GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 165507 rows, 84810 columns and 12183709 nonzeros
# Model fingerprint: 0xbb2f1e12
# Variable types: 0 continuous, 84810 integer (4114 binary)
# Coefficient statistics:
#   Matrix range     [1e-13, 9e+04]
#   Objective range  [2e+04, 2e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+00, 8e+01]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 3.151708e+07
# Presolve removed 161393 rows and 19450 columns (presolve time = 19s) ...
# Presolve removed 164382 rows and 19450 columns (presolve time = 20s) ...
# Presolve removed 164382 rows and 19450 columns
# Presolve time: 20.99s
# Presolved: 1125 rows, 65360 columns, 129747 nonzeros
# Variable types: 0 continuous, 65360 integer (1048 binary)
# Found heuristic solution: objective 3.151708e+07
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0849980e+07   1.125000e+02   6.237200e+10     22s
#       85    2.2016132e+08   0.000000e+00   1.305981e+07     22s
#     7597    1.8115294e+07   0.000000e+00   0.000000e+00     22s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.811529e+07, 7597 iterations, 0.40 seconds (0.17 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.8115e+07    0   50 3.1517e+07 1.8115e+07  42.5%     -   22s
# H    0     0                    2.740155e+07 1.8115e+07  33.9%     -   22s
# H    0     0                    2.719855e+07 1.8115e+07  33.4%     -   22s
# H    0     0                    2.255731e+07 1.8115e+07  19.7%     -   23s
# H    0     0                    1.826655e+07 1.8115e+07  0.83%     -   27s
# H    0     0                    1.826655e+07 1.8115e+07  0.83%     -   28s
#      0     0 1.8115e+07    0   98 1.8267e+07 1.8115e+07  0.83%     -   28s
#      0     0 1.8115e+07    0  102 1.8267e+07 1.8115e+07  0.83%     -   30s
#      0     0 1.8115e+07    0  144 1.8267e+07 1.8115e+07  0.83%     -   31s
#      0     0 1.8115e+07    0  159 1.8267e+07 1.8115e+07  0.83%     -   31s
#      0     0 1.8115e+07    0  190 1.8267e+07 1.8115e+07  0.83%     -   31s
#      0     0 1.8115e+07    0  190 1.8267e+07 1.8115e+07  0.83%     -   32s
# H    0     0                    1.826655e+07 1.8115e+07  0.83%     -   36s
#      0     2 1.8115e+07    0  190 1.8267e+07 1.8115e+07  0.83%     -   36s
# ...
#     23    29 1.8416e+07    5  199 1.8553e+07 1.8416e+07  0.74%  65.9   40s
#    116   248 1.8416e+07   27  151 1.8553e+07 1.8416e+07  0.74%  28.3   48s
#    247   760 1.8416e+07   75  104 1.8553e+07 1.8416e+07  0.74%  27.5   55s
#    759  1049 1.8416e+07  229   33 1.8553e+07 1.8416e+07  0.74%  27.9   63s
#   1048  1523 1.8416e+07  349   28 1.8553e+07 1.8416e+07  0.74%  28.8   69s
#   1522  2208 1.8416e+07  499   24 1.8553e+07 1.8416e+07  0.74%  27.7   73s
#   2207  2858 1.8416e+07  650   18 1.8553e+07 1.8416e+07  0.74%  25.7   79s
#   2857  3913 1.8416e+07  769   12 1.8553e+07 1.8416e+07  0.74%  22.9   83s
# H 3117  3913                    1.850360e+07 1.8416e+07  0.47%  22.2   84s
# H 3941  4168                    1.850360e+07 1.8416e+07  0.47%  20.3   97s
# H 3989  4168                    1.850360e+07 1.8416e+07  0.47%  20.3   97s
# H 3990  4168                    1.850360e+07 1.8416e+07  0.47%  20.3   97s
# H 4132  4168                    1.850359e+07 1.8416e+07  0.47%  19.8   97s
# H 4226  4211                    1.850359e+07 1.8416e+07  0.47%  19.6  101s
# H 4269  4211                    1.850359e+07 1.8416e+07  0.47%  19.7  101s
#   4275  4628 1.8416e+07   20   44 1.8504e+07 1.8416e+07  0.47%  19.9  105s
# H 4299  4628                    1.850359e+07 1.8416e+07  0.47%  20.0  105s
#   4695  4630 1.8416e+07  142   55 1.8504e+07 1.8416e+07  0.47%  19.9  110s
#   4698  4632 1.8416e+07  280  199 1.8504e+07 1.8416e+07  0.47%  19.9  115s
#   4701  4634 1.8416e+07  242  236 1.8504e+07 1.8416e+07  0.47%  19.9  120s
#
# Cutting planes:
#   Gomory: 5
#   Lift-and-project: 2
#   Implied bound: 340
#   MIR: 36
#   StrongCG: 6
#   Flow cover: 64
#   Zero half: 5
#   Relax-and-lift: 38
#
# Explored 4701 nodes (119446 simplex iterations) in 121.71 seconds (62.57 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 1.85036e+07 1.85036e+07 1.85036e+07 ... 1.85528e+07
#
# Solve interrupted
# Best objective 1.850359135764e+07, best bound 1.841582578295e+07, gap 0.4743%
#
# User-callback calls 13551, time in user-callback 0.11 sec
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Set parameter TimeLimit to value 10000
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1145G7 @ 2.60GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 165157 rows, 84460 columns and 9890649 nonzeros
# Model fingerprint: 0x23e6a4d4
# Variable types: 0 continuous, 84460 integer (3764 binary)
# Coefficient statistics:
#   Matrix range     [1e-13, 9e+04]
#   Objective range  [2e+04, 2e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+00, 8e+01]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 3.022918e+07
# Presolve removed 161393 rows and 19100 columns (presolve time = 14s) ...
# Presolve removed 164032 rows and 19100 columns (presolve time = 15s) ...
# Presolve removed 164032 rows and 19100 columns
# Presolve time: 16.20s
# Presolved: 1125 rows, 65360 columns, 129747 nonzeros
# Variable types: 0 continuous, 65360 integer (1048 binary)
# Found heuristic solution: objective 3.022918e+07
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0039982e+07   1.050000e+02   6.049300e+10     17s
#       81    2.1887342e+08   0.000000e+00   1.305989e+07     17s
#     8243    1.6762909e+07   0.000000e+00   0.000000e+00     17s
# Concurrent spin time: 0.01s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.676291e+07, 8243 iterations, 0.42 seconds (0.17 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.6763e+07    0   53 3.0229e+07 1.6763e+07  44.5%     -   17s
# H    0     0                    2.672265e+07 1.6763e+07  37.3%     -   17s
# H    0     0                    2.651965e+07 1.6763e+07  36.8%     -   17s
# H    0     0                    2.094033e+07 1.6763e+07  19.9%     -   17s
# H    0     0                    1.677565e+07 1.6763e+07  0.08%     -   23s
#      0     0 1.6763e+07    0  100 1.6776e+07 1.6763e+07  0.08%     -   24s
#      0     0 1.6763e+07    0  105 1.6776e+07 1.6763e+07  0.08%     -   26s
#      0     0 1.6763e+07    0  161 1.6776e+07 1.6763e+07  0.08%     -   26s
#      0     0 1.6763e+07    0  154 1.6776e+07 1.6763e+07  0.08%     -   27s
#      0     0 1.6763e+07    0  183 1.6776e+07 1.6763e+07  0.08%     -   27s
#      0     0 1.6763e+07    0  183 1.6776e+07 1.6763e+07  0.08%     -   28s
#      0     2 1.6763e+07    0  183 1.6776e+07 1.6763e+07  0.08%     -   30s
#     45    82 1.6763e+07   11  187 1.6776e+07 1.6763e+07  0.08%  30.1   35s
#    177   512 1.6763e+07   51   99 1.6776e+07 1.6763e+07  0.08%  36.7   43s
#    513   861 1.6763e+07  139   99 1.6776e+07 1.6763e+07  0.08%  42.3   47s
#    862  1167 1.6763e+07  241   93 1.6776e+07 1.6763e+07  0.08%  46.2   52s
#   1168  1589 1.6763e+07  316   95 1.6776e+07 1.6763e+07  0.08%  47.8   57s
#   1590  2067 1.6763e+07  421   92 1.6776e+07 1.6763e+07  0.08%  46.3   62s
#   2070  2347 1.6763e+07  512   38 1.6776e+07 1.6763e+07  0.08%  39.1   66s
#   2350  2719 1.6763e+07  584   27 1.6776e+07 1.6763e+07  0.08%  35.0   70s
#   3197  3753 1.6763e+07  802   12 1.6776e+07 1.6763e+07  0.08%  28.6   79s
#   3809  4101 1.6763e+07    7  138 1.6776e+07 1.6763e+07  0.08%  27.5   83s
#   4227  4389 1.6763e+07   73   25 1.6776e+07 1.6763e+07  0.08%  27.9   96s
#   4527  4392 1.6763e+07  167   94 1.6776e+07 1.6763e+07  0.08%  28.7  101s
#   4531  4395 1.6763e+07   71  245 1.6776e+07 1.6763e+07  0.08%  28.7  105s
#   4535  4397 1.6763e+07   14  237 1.6776e+07 1.6763e+07  0.08%  28.6  112s
#   4536  4401 1.6763e+07   14  237 1.6776e+07 1.6763e+07  0.08%  30.4  119s
#   4542  4407 1.6763e+07   16  242 1.6776e+07 1.6763e+07  0.08%  30.6  120s
#
# Cutting planes:
#   Gomory: 4
#   Lift-and-project: 2
#   Implied bound: 354
#   MIR: 9
#   StrongCG: 1
#   Flow cover: 45
#   Zero half: 5
#   Network: 1
#   Relax-and-lift: 27
#
# Explored 4546 nodes (147691 simplex iterations) in 120.51 seconds (70.33 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 1.67756e+07 2.09403e+07 2.65196e+07 ... 3.02292e+07
#
# Solve interrupted
# Best objective 1.677564605479e+07, best bound 1.676290872133e+07, gap 0.0759%
#
# User-callback calls 13285, time in user-callback 0.16 sec
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Set parameter TimeLimit to value 10000
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1145G7 @ 2.60GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 165430 rows, 84733 columns and 11649512 nonzeros
# Model fingerprint: 0x6296754c
# Variable types: 0 continuous, 84733 integer (4037 binary)
# Coefficient statistics:
#   Matrix range     [1e-13, 9e+04]
#   Objective range  [2e+04, 2e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+00, 8e+01]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 3.115138e+07
# Presolve removed 161393 rows and 19373 columns (presolve time = 17s) ...
# Presolve removed 164305 rows and 19373 columns
# Presolve time: 19.43s
# Presolved: 1125 rows, 65360 columns, 129747 nonzeros
# Variable types: 0 continuous, 65360 integer (1048 binary)
# Found heuristic solution: objective 3.115138e+07
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0619980e+07   1.106250e+02   6.049300e+10     21s
#       83    2.1979562e+08   0.000000e+00   1.305995e+07     21s
#     7759    1.7731284e+07   0.000000e+00   0.000000e+00     21s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.773128e+07, 7759 iterations, 0.35 seconds (0.17 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.7731e+07    0   49 3.1151e+07 1.7731e+07  43.1%     -   20s
# H    0     0                    2.683285e+07 1.7731e+07  33.9%     -   20s
# H    0     0                    2.214245e+07 1.7731e+07  19.9%     -   21s
# H    0     0                    1.790085e+07 1.7731e+07  0.95%     -   25s
#      0     0 1.7731e+07    0   79 1.7901e+07 1.7731e+07  0.95%     -   25s
# H    0     0                    1.785169e+07 1.7731e+07  0.67%     -   27s
#      0     0 1.7731e+07    0   83 1.7852e+07 1.7731e+07  0.67%     -   27s
#      0     0 1.7731e+07    0  138 1.7852e+07 1.7731e+07  0.67%     -   28s
# H    0     0                    1.777477e+07 1.7731e+07  0.24%     -   28s
#      0     0 1.7731e+07    0  155 1.7775e+07 1.7731e+07  0.24%     -   28s
#      0     0 1.7731e+07    0  173 1.7775e+07 1.7731e+07  0.24%     -   29s
#      0     0 1.7731e+07    0  173 1.7775e+07 1.7731e+07  0.24%     -   29s
# H    0     0                    1.777477e+07 1.7731e+07  0.24%     -   32s
#      0     2 1.7731e+07    0  173 1.7775e+07 1.7731e+07  0.24%     -   32s
#     27    32 1.7731e+07    6  179 1.7775e+07 1.7731e+07  0.24%  62.9   36s
# H   28    32                    1.777477e+07 1.7731e+07  0.24%  60.6   36s
#     83   252 1.7731e+07   20  160 1.7775e+07 1.7731e+07  0.24%  35.7   41s
#    251   499 1.7731e+07   82   64 1.7775e+07 1.7731e+07  0.24%  29.1   48s
#    498   869 1.7731e+07  174   42 1.7775e+07 1.7731e+07  0.24%  24.0   54s
#    868  1114 1.7731e+07  264   35 1.7775e+07 1.7731e+07  0.24%  21.9   60s
#   1113  1661 1.7731e+07  279   35 1.7775e+07 1.7731e+07  0.24%  24.4   65s
#   1660  2394 1.7731e+07  443   28 1.7775e+07 1.7731e+07  0.24%  25.6   70s
#   2393  2868 1.7731e+07  585   22 1.7775e+07 1.7731e+07  0.24%  22.1   81s
#   2867  3886 1.7731e+07  733   17 1.7775e+07 1.7731e+07  0.24%  20.6   86s
# H 3897  4285                    1.777477e+07 1.7731e+07  0.24%  18.7   91s
# H 3941  4285                    1.777477e+07 1.7731e+07  0.24%  18.5   91s
#   4484  4740 1.7731e+07   52  106 1.7775e+07 1.7731e+07  0.24%  18.7   98s
# H 4547  4740                    1.777477e+07 1.7731e+07  0.24%  19.6   98s
#   4782  4741 1.7731e+07  757  173 1.7775e+07 1.7731e+07  0.24%  20.5  100s
#   4787  4744 1.7731e+07   53  171 1.7775e+07 1.7731e+07  0.24%  20.5  105s
#   4793  4748 1.7731e+07  659  232 1.7775e+07 1.7731e+07  0.24%  20.4  113s
#   4800  4758 1.7731e+07   15  223 1.7775e+07 1.7731e+07  0.24%  23.5  115s
#   4838  4800 1.7731e+07   20  223 1.7775e+07 1.7731e+07  0.24%  23.9  120s
#
# Cutting planes:
#   Gomory: 3
#   Lift-and-project: 10
#   Implied bound: 432
#   MIR: 21
#   StrongCG: 1
#   Flow cover: 1
#   Zero half: 6
#   Network: 1
#   Relax-and-lift: 8
#
# Explored 4859 nodes (124132 simplex iterations) in 121.13 seconds (67.49 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 1.77748e+07 1.77748e+07 1.77748e+07 ... 2.68328e+07
#
# Solve interrupted
# Best objective 1.777476876621e+07, best bound 1.773128396668e+07, gap 0.2446%
#
# User-callback calls 13758, time in user-callback 0.13 sec
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Set parameter TimeLimit to value 10000
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1145G7 @ 2.60GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 165346 rows, 84649 columns and 11078828 nonzeros
# Model fingerprint: 0xf31b3782
# Variable types: 0 continuous, 84649 integer (3953 binary)
# Coefficient statistics:
#   Matrix range     [1e-13, 9e+04]
#   Objective range  [2e+04, 2e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+00, 8e+01]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 3.092878e+07
# Presolve removed 161393 rows and 19289 columns (presolve time = 16s) ...
# Presolve removed 164221 rows and 19289 columns
# Presolve time: 17.36s
# Presolved: 1125 rows, 65360 columns, 129747 nonzeros
# Variable types: 0 continuous, 65360 integer (1048 binary)
# Found heuristic solution: objective 3.092878e+07
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0479981e+07   1.078750e+02   6.049300e+10     19s
#       83    2.1957302e+08   0.000000e+00   1.305995e+07     19s
#     8520    1.7497538e+07   0.000000e+00   0.000000e+00     19s
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.749754e+07, 8520 iterations, 0.39 seconds (0.17 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.7498e+07    0   53 3.0929e+07 1.7498e+07  43.4%     -   18s
# H    0     0                    2.742225e+07 1.7498e+07  36.2%     -   18s
# H    0     0                    2.721925e+07 1.7498e+07  35.7%     -   18s
# H    0     0                    2.151385e+07 1.7498e+07  18.7%     -   20s
# H    0     0                    1.767825e+07 1.7498e+07  1.02%     -   24s
# H    0     0                    1.767825e+07 1.7498e+07  1.02%     -   24s
# H    0     0                    1.767825e+07 1.7498e+07  1.02%     -   24s
#      0     0 1.7498e+07    0   95 1.7678e+07 1.7498e+07  1.02%     -   24s
#      0     0 1.7498e+07    0   99 1.7678e+07 1.7498e+07  1.02%     -   27s
#      0     0 1.7498e+07    0  150 1.7678e+07 1.7498e+07  1.02%     -   27s
#      0     0 1.7498e+07    0  164 1.7678e+07 1.7498e+07  1.02%     -   27s
#      0     0 1.7498e+07    0  186 1.7678e+07 1.7498e+07  1.02%     -   28s
#      0     0 1.7498e+07    0  186 1.7678e+07 1.7498e+07  1.02%     -   28s
#      0     2 1.7498e+07    0  186 1.7678e+07 1.7498e+07  1.02%     -   32s
#     27    32 1.7498e+07    6  172 1.7678e+07 1.7498e+07  1.02%  42.5   36s
#    106   249 1.7498e+07   17  102 1.7678e+07 1.7498e+07  1.02%  23.5   41s
#    248   518 1.7498e+07   50  103 1.7678e+07 1.7498e+07  1.02%  41.9   46s
# H  517   800                    1.762909e+07 1.7498e+07  0.75%  54.8   54s
# H  799  1210                    1.755217e+07 1.7498e+07  0.31%  56.6   61s
#   1209  1699 1.7498e+07  243   97 1.7552e+07 1.7498e+07  0.31%  59.3   66s
#   1698  2286 1.7498e+07  370   95 1.7552e+07 1.7498e+07  0.31%  57.6   72s
#   2285  2474 1.7498e+07  514   29 1.7552e+07 1.7498e+07  0.31%  48.6   84s
#   2473  3033 1.7498e+07  614   19 1.7552e+07 1.7498e+07  0.31%  45.4   89s
#   3032  3574 1.7498e+07  720   16 1.7552e+07 1.7498e+07  0.31%  39.6   95s
#   3573  4337 1.7498e+07  826   13 1.7552e+07 1.7498e+07  0.31%  37.0  100s
#   4857  5679 1.7498e+07  139   40 1.7552e+07 1.7498e+07  0.31%  32.4  109s
#   5720  5680 1.7498e+07  103  186 1.7552e+07 1.7498e+07  0.31%  29.4  111s
#   5723  5682 1.7498e+07  335   92 1.7552e+07 1.7498e+07  0.31%  29.4  115s
#   5728  5685 1.7498e+07  699  201 1.7552e+07 1.7498e+07  0.31%  29.4  120s
#
# Cutting planes:
#   Gomory: 4
#   Lift-and-project: 3
#   Implied bound: 307
#   MIR: 23
#   StrongCG: 5
#   Flow cover: 50
#   Zero half: 10
#   Relax-and-lift: 23
#
# Explored 5728 nodes (190182 simplex iterations) in 120.83 seconds (68.39 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 1.75522e+07 1.76291e+07 1.76782e+07 ... 3.09288e+07
#
# Solve interrupted
# Best objective 1.755216824793e+07, best bound 1.749753838945e+07, gap 0.3112%
#
# User-callback calls 15830, time in user-callback 0.14 sec

# %%
total_drones.to_csv('5100 0.999.csv', index=False)

# %% [markdown]
# Probabilistic model

# %% [markdown]
# Probabilistic model with relaxed constraints

# %%
#Redefine set L
L = list()
for k, j in itertools.product(K.index, J.index):
    if dist_KJ[(k, j)] <= B:
        L.append((k, j))
        

#Redefine set P
P = list()
for i, k in itertools.product(I.index, K.index):
    if dist_IK[(i, k)] <= B:
        P.append((i, k))

#Redefine sets M_kj

M_kj = {}
M_interim = []

for (k, j) in L:
    for i in I.index:
        if dist_JI[j, i] <= S:
            if dist_JI[j, i] + dist_IK[i, k] <= B:
                M_interim.append(i)
    M_kj[(k, j)] = M_interim
    M_interim = []

M_kj_final = {key : val for key, val in M_kj.items() if val != []}  

KJ_feas = list(M_kj_final.keys())


#Redefine sets N_i

N_i = {}
N_interim = []

for i in I.index:
    for (k, j) in L:
        if dist_JI[j, i] <= S:
            if dist_JI[j, i] + dist_IK[i, k] <= B:
                N_interim.append((k, j))
    N_i[i] = N_interim
    N_interim = []
    
N_i_final = {key : val for key, val in N_i.items() if val != []}   
 
I_feas = list(N_i_final.keys())


#Redefine sets O_j

O_j = {}
O_interim = []

for j in J.index:
    for (i, k) in P:
        if dist_JI[j, i] <= S:
            if dist_JI[j, i] + dist_IK[i, k] <= B:
                O_interim.append((i, k))
    O_j[j] = O_interim
    O_interim = []
    
O_j_final = {key : val for key, val in O_j.items() if val != []}   
 
J_feas = list(O_j_final.keys())


I_feasG = []
for i in I_feas:
    for g in range(1, g_i[i] + 1):
        I_feasG.append((i, g))
        

h_ig = {}
for (i, g) in I_feasG:
    h_ig[(i, g)] = math.log(theta_ran_i[i].cdf(l_i[i] + g)) - math.log(theta_ran_i[i].cdf(l_i[i] + g - 1))


phi = float(math.log(p) - sum(theta_ran_i[i].cdf(l_i[i]) for i in I_feas))

# %%
model_prob_rel = gp.Model('Probabilistic model with relaxation')

x_ikj = model_prob_rel.addVars(I.index, L, vtype = GRB.INTEGER, name = 'x_ikj')
y_j = model_prob_rel.addVars(J.index, vtype = GRB.BINARY, name = 'y_j')
z_ig = model_prob_rel.addVars(IG, vtype = GRB.BINARY, name = 'z_ig')

model_prob_rel.addConstr((gp.quicksum(h_ig[ig] * z_ig[ig] for ig in I_feasG)) >= phi, name = 'c15')
model_prob_rel.addConstrs((gp.quicksum(x_ikj[i, k, j] for (k, j) in N_i_final[i]) == l_i[i] + gp.quicksum(z_ig) for (i, g) in I_feasG), name = 'c16')

model_prob_rel.addConstrs((gp.quicksum(x_ikj[i, k, j] for (i, k) in O_j_final[j]) <= q_j[j] * y_j[j] for j in J_feas), name = 'c4')
model_prob_rel.addConstrs(((dist_JI[(j, i)] + dist_IK[(i, k)]) * x_ikj[i, k, j] <= B * x_ikj[i, k, j]
                  for i in I_feas for (k, j) in KJ_feas), name = 'c5')
model_prob_rel.addConstrs((dist_JI[(j, i)] * x_ikj[i, k, j] <= S * x_ikj[i, k, j] for i in I_feas for (k, j) in KJ_feas), name = 'c6')
model_prob_rel.addConstrs((y_j[k] == 1 for k in K.index), name = 'c7')


model_prob_rel.setObjective(gp.quicksum(alpha * x_ikj[i, k, j] + gamma * (dist_JI[(j, i)] + dist_IK[(i, k)] + dist_KJ[(k, j)]) * x_ikj[i, k, j] for i in I_feas for (k, j) in KJ_feas) + gp.quicksum(beta[j] * y_j[j] for j in J_feas), GRB.MINIMIZE)
model_prob_rel.setParam('TimeLimit', hardlimit)
model_prob_rel.optimize(softtime)

# %% [markdown]
# Deterministic model with relaxed constraints

# %%
model_det_rel = gp.Model('Deterministic model with relaxation')

x_ikj = model_det_rel.addVars(I.index, L, vtype = GRB.INTEGER, name = 'x_ikj')
y_j = model_det_rel.addVars(J.index, vtype = GRB.BINARY, name = 'y_j')

model_det_rel.addConstrs((gp.quicksum(x_ikj[i, k, j] for (k, j) in N_i_final[i]) >= theta_det[i] for i in I_feas), name = 'c2')

model_det_rel.addConstrs((gp.quicksum(x_ikj[i, k, j] for (i, k) in O_j_final[j]) <= q_j[j] * y_j[j] for j in J_feas), name = 'c4')
model_det_rel.addConstrs(((dist_JI[(j, i)] + dist_IK[(i, k)]) * x_ikj[i, k, j] <= B * x_ikj[i, k, j]
                  for i in I_feas for (k, j) in KJ_feas), name = 'c5')
model_det_rel.addConstrs((dist_JI[(j, i)] * x_ikj[i, k, j] <= S * x_ikj[i, k, j] for i in I_feas for (k, j) in KJ_feas), name = 'c6')
model_det_rel.addConstrs((y_j[k] == 1 for k in K.index), name = 'c7')

model_det_rel.setObjective(gp.quicksum(alpha * x_ikj[i, k, j] + gamma * (dist_JI[(j, i)] + dist_IK[(i, k)] + dist_KJ[(k, j)]) * x_ikj[i, k, j] for i in I_feas for (k, j) in KJ_feas) + gp.quicksum(beta[j] * y_j[j] for j in J_feas), GRB.MINIMIZE)
model_det_rel.setParam('TimeLimit', hardlimit)
model_det_rel.optimize(softtime)
